# %%
import pickle
import numpy as np

# %%
lyrics = pickle.load(open("broadway_lyrics_v2.pkl", "rb"))

# %%
lyrics.keys()
# Out:
# dict_keys(['beautifulgamethe', 'boysfromsyracusethe', 'brigadoon', 'frozen', 'jennie', 'wildcat', 'lionking', 'newsies', 'howtosucceedinbusinesswithoutreallytrying', 'aintmisbehavin', 'gentlemansguidetoloveandmurdera', 'myfairlady', 'ace', 'highsociety', 'janeeyre', 'littlemermaid', 'nexttonormal', 'honk', 'pippin', 'seewhatiwannasee', 'andrewlloydwebberdivas', 'mammamia', 'applause', '70girls70', 'actthe', 'lesmiserables', 'marguerite', 'byebyebirdie', 'aida', 'warpaint', 'bareapopopera', 'showboat', 'seussical', 'scarletpimpernelthe', 'sweeneytoddthedemonbarberoffleetstreet', 'theyreplayingoursong', 'tellmeonasunday', 'lestat', 'rinkthe', 'promisespromises', 'shout', 'childrensletterstogod', 'charlieandalgernon', 'newbraina', 'bigriver', 'sisteractthemusical', 'southpacific', 'bellsareringing', 'highschoolmusical3senioryear', 'saydarling', 'lacageauxfolles', 'sugar', 'gigi', 'intheheights', 'curtains', 'iloveyoubecause', 'luckystiff', 'bestfootforward', 'civilwarthe', 'burnthefloor
# ...

# %%
lyrics["frozen"]
# Out:
# {'currently_playing': True,
#  'lyrics': ['Vuelie/ Let the Sun Shine On',
#   'ENSEMBLE:',
#   'Na na na heyana',
#   'Nahiyaha naha',
#   'Naheya heya na yanuwa',
#   'Hanahe yunuwana',
#   'Na na na heyana',
#   'Hahiyaha naha',
#   'Naheya heya na yanuwa',
#   'Hanahe yunuwana',
#   'Na na na heyana',
#   'Nahiyaha naha',
#   'Naheya heya na yanuwa',
#   'Hanahe yunuwana',
#   'YOUNG ANNA:',
#   'Do you want to build a snowman?',
#   "C'mon let's go and play",
#   'YOUNG ELSA:',
#   'I can cover this whole place in snow',
#   "I'm not supposed to though",
#   'YOUNG ANNA:',
#   'Yeah, just do it anyway',
#   'Do it for your sister!',
#   'Elsa please, oh please',
#   "I can't do the things you do",
#   "That's what I'm talking about!!",
#   'YOUNG ELSA & YOUNG ANNA:',
#   'You really want to build that snowman?',
#   'You know I do',
#   "We'll stay up late and build that snowman!",
#   'Yes',
#   'Me and you',
#   'ENSEMBLE:',
#   'Nah nah yanana',
#   'Nah nah yanana',
# ...

# %%
now_playing = 0
for show in lyrics:
    if lyrics[show]["currently_playing"]:
        now_playing += 1

# %%
now_playing
# Out:
# 23

# %%
num_songs = [None]*len(lyrics.keys())
i = 0
for show in lyrics:
    num_songs[i] = len(lyrics[show]["song_titles"])
    i += 1

# %%
print(num_songs)
# Out:
# [22, 13, 15, 21, 0, 0, 20, 16, 28, 25, 22, 16, 1, 4, 25, 29, 37, 18, 18, 29, 15, 23, 6, 14, 11, 33, 14, 18, 25, 5, 37, 20, 28, 25, 29, 12, 16, 18, 4, 21, 20, 14, 1, 24, 19, 20, 19, 16, 13, 0, 15, 12, 10, 23, 21, 18, 20, 3, 26, 9, 14, 3, 17, 16, 19, 10, 15, 15, 6, 28, 0, 16, 16, 0, 14, 20, 17, 6, 18, 2, 11, 7, 16, 34, 16, 20, 14, 29, 15, 15, 24, 10, 22, 20, 17, 15, 28, 22, 14, 13, 14, 13, 0, 12, 3, 22, 15, 16, 6, 0, 25, 21, 18, 24, 15, 33, 18, 2, 16, 1, 24, 21, 21, 1, 20, 26, 18, 17, 0, 27, 16, 20, 3, 35, 23, 20, 10, 22, 20, 14, 20, 18, 42, 25, 19, 16, 17, 0, 5, 18, 23, 18, 18, 43, 16, 13, 2, 16, 0, 18, 15, 1, 1, 33, 19, 23, 1, 21, 14, 18, 23, 10, 8, 21, 21, 19, 17, 15, 25, 17, 23, 33, 11, 18, 21, 12, 23, 19, 17, 18, 0, 13, 29, 30, 9, 14, 19, 16, 13, 18, 15, 14, 14, 38, 16, 22, 20, 20, 2, 27, 24, 23, 19, 16, 8, 38, 5, 23, 18, 13, 0, 3, 0, 18, 4, 17, 22, 9, 21, 24, 17, 1, 27, 13, 26, 12, 32, 30, 26, 26, 19, 3, 10, 20, 17, 35, 7, 22, 1, 1, 11, 12, 8, 11, 49, 14, 21, 2, 0, 25, 0, 33, 25,
# ...

# %%
for show in lyrics:
    if len(lyrics[show]["song_titles"]) == 124:
        print(show)
# Out:
# disney60yearsofmusicalmagic
