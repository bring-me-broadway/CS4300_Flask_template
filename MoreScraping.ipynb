# %%
import pickle
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup
import string

def simple_get(url):
    """
    Attempts to get the content at `url` by making an HTTP GET request.
    If the content-type of response is some kind of HTML/XML, return the
    text content, otherwise return None.
    """
    try:
        with closing(get(url, stream=True)) as resp:
            if is_good_response(resp):
                return resp.content
            else:
                return None

    except RequestException as e:
        log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        return None


def is_good_response(resp):
    """
    Returns True if the response seems to be HTML, False otherwise.
    """
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 
            and content_type is not None 
            and content_type.find('html') > -1)


def log_error(e):
    """
    It is always a good idea to log errors. 
    This function just prints them, but you can
    make it do anything.
    """
    print(e)

# %%
show_urls = []
letters = list(string.ascii_lowercase)
letters.append('19')
for letter in letters:
    letter_html = simple_get('https://www.allmusicals.com/' + letter + '.htm')
    letter_soup = BeautifulSoup(letter_html, 'html.parser')
    for a in letter_soup.find_all('a'):
        show_link = a.get('href')
        if "/" + letter + "/" in show_link:
            show_urls.append(show_link)

# %%
show_urls
# Out:
# ['/a/adayinhollywoodanightintheukraine.htm',
#  '/a/ace.htm',
#  '/a/acrosstheuniverse.htm',
#  '/a/actthe.htm',
#  '/a/addamsfamilythe.htm',
#  '/a/addingmachine.htm',
#  '/a/adriftinmacao.htm',
#  '/a/adventuresoftomsawyerthe.htm',
#  '/a/aida.htm',
#  '/a/aintmisbehavin.htm',
#  '/a/ainttooproud.htm',
#  '/a/aladdin.htm',
#  '/a/alasalackzorrosback.htm',
#  '/a/allshookup.htm',
#  '/a/allegro.htm',
#  '/a/altarboyz.htm',
#  '/a/americanidiot.htm',
#  '/a/americaninparisan.htm',
#  '/a/americanmall.htm',
#  '/a/anastasia.htm',
#  '/a/andrewlloydwebberdivas.htm',
#  '/a/annakarenina.htm',
#  '/a/annie.htm',
#  '/a/anniegetyourgun.htm',
#  '/a/anyonecanwhistle.htm',
#  '/a/anythinggoes.htm',
#  '/a/applause.htm',
#  '/a/appletreethe.htm',
#  '/a/arkthe.htm',
#  '/a/asthousandscheer.htm',
#  '/a/aspectsoflove.htm',
#  '/a/assassins.htm',
#  '/a/avenueq.htm',
#  '/a/aladdin.htm',
#  '/b/babesinarms.htm',
#  '/b/baby.htm',
#  '/b/badgirls.htm',
#  '/b/bajour.htm',
#  '/b/bakerswifethe.htm',
#  '/b/bandsvisit.htm',
#  '/b/bandstand.htm',
#  '/b/bareapopopera.htm',
#  '/b/barkthemusical.htm',
#  '/b/barnum.htm',
#  '/b/batboy.htm',
#  '/b/bemorechill.htm',
#  '/b/beautifulgamethe.htm',
#  '/b/beautifulthecaroleking.htm',
#  '/b/bellsareringing.htm',
#  '/b/benfranklininparis.htm',
#  '/b/bernardaalba.htm',
#  '/b/bestfootforward.htm',
#  '/b/bestlittlewhorehouseintexasthe.htm',
#  '/b/bestofbroadwaythe.htm',
#  '/b/big.htm',
#  '/b/bigfish.htm',
#  '/b/bigriver.htm',
#  '/b/billyelliot.htm',
#  '/b/bloodbrothers.htm',
#  '/b/bombaydreams.htm',
#  '/b/bookofmormonthe.htm',
#  '/b/bounce.htm',
#  '/b/boyfriendthe.htm',
#  '/b/boyfromozthe.htm',
#  '/b/boysfromsyracusethe.htm',
#  '/b/bridgesofmadisoncountythe.htm',
#  '/b/brigadoon.htm',
#  '/b/brightlightsbigcity.htm',
#  '/b/bringindanoisebringindafunk.htm',
#  '/b/bringiton.htm',
#  '/b/bronxtale.htm',
#  '/b/brooklyn.htm',
#  '/b/bulletsoverbroadway.htm',
#  '/b/burnthefloor.htm',
#  '/b/buskeralley.htm',
#  '/b/byjeeves.htm',
#  '/b/byebyebirdie.htm',
#  '/b/bookofmormonthe.htm',
#  '/b/beautifulthecaroleking.htm',
#  '/c/cabaret.htm',
#  '/c/calamityjane.htm',
#  '/c/callmemadam.htm',
#  '/c/camelot.htm',
#  '/c/cancan.htm',
#  '/c/candide.htm',
#  '/c/cannibal.htm',
#  '/c/carnival.htm',
#  '/c/carolineorchange.htm',
#  '/c/carousel.htm',
#  '/c/catchmeifyoucan.htm',
#  '/c/cateredaffaira.htm',
#  '/c/cats.htm',
#  '/c/chaplin.htm',
#  '/c/charlieandalgernon.htm',
#  '/c/charlieandthechocolatefactory.htm',
#  '/c/chess.htm',
#  '/c/chessinconcertlive.htm',
#  '/c/chicago.htm',
#  '/c/childrenofeden.htm',
#  '/c/childrensletterstogod.htm',
#  '/c/chittychittybangbang.htm',
#  '/c/choruslinea.htm',
#  '/c/christmascarola.htm',
#  '/c/cinderellasongsfromtheclassicfairytale.htm',
#  '/c/cityofangels.htm',
#  '/c/civilwarthe.htm',
#  '/c/civilwarthecompleteworkthe.htm',
#  '/c/classacta.htm',
#  '/c/closerthanever.htm',
#  '/c/colma.htm',
#  '/c/colorpurplethe.htm',
#  '/c/comefromaway.htm',
#  '/c/commentarythemusical.htm',
#  '/c/company.htm',
#  '/c/connecticutyankeea.htm',
#  '/c/contact.htm',
#  '/c/copacabana.htm',
#  '/c/corpsebride.htm',
#  '/c/crazyforyou.htm',
#  '/c/crybaby.htm',
#  '/c/curtains.htm',
#  '/c/comefromaway.htm',
#  '/d/damnyankees.htm',
#  '/d/danceofthevampires.htm',
#  '/d/dearevanhansen.htm',
#  '/d/dearworld.htm',
#  '/d/dirtyrottenscoundrels.htm',
#  '/d/disneysbeautyandthebeast.htm',
#  '/d/disney60yearsofmusicalmagic.htm',
#  '/d/doblackpatentleathershoesreallyreflectup.htm',
#  '/d/doihearawaltz.htm',
#  '/d/doremi.htm',
#  '/d/dracula.htm',
#  '/d/dreamgirls.htm',
#  '/d/drowsychaperonethe.htm',
#  '/d/dearevanhansen.htm',
#  '/e/edgesasongcycle.htm',
#  '/e/elegiesasongcycle.htm',
#  '/e/ernestinlove.htm',
#  '/e/evildead.htm',
#  '/e/evita.htm',
#  '/f/facethemusic.htm',
#  '/f/falsettoland.htm',
#  '/f/falsettos.htm',
#  '/f/fame.htm',
#  '/f/famebecomesme.htm',
#  '/f/fanny.htm',
#  '/f/fantasticksthe.htm',
#  '/f/fiddlerontheroof.htm',
#  '/f/findingneverland.htm',
#  '/f/finiansrainbow.htm',
#  '/f/fiorello.htm',
#  '/f/firstdate.htm',
#  '/f/fivecourselove.htm',
#  '/f/fiveguysnamedmoe.htm',
#  '/f/floratheredmenace.htm',
#  '/f/flowerdrumsong.htm',
#  '/f/floydcollins.htm',
#  '/f/follies.htm',
#  '/f/footloose.htm',
#  '/f/forbiddenbroadwaygoestorehab.htm',
#  '/f/forbiddenbroadwayvols14.htm',
#  '/f/foreverplaid.htm',
#  '/f/fosse.htm',
#  '/f/frankensteinanewmusical.htm',
#  '/f/frogsthe.htm',
#  '/f/frozen.htm',
#  '/f/fullmontythe.htm',
#  '/f/funhome.htm',
#  '/f/funnygirl.htm',
#  '/f/funnythinghappenedonthewaytotheforuma.htm',
#  '/g/gaydivorcethe.htm',
#  '/g/gentlemansguidetoloveandmurdera.htm',
#  '/g/gentlemenpreferblondes.htm',
#  '/g/georgem.htm',
#  '/g/ghostthemusical.htm',
#  '/g/gigi.htm',
#  '/g/gloriousonesthe.htm',
#  '/g/glorydays.htm',
#  '/g/godspell.htm',
#  '/g/goldenboy.htm',
#  '/g/gonemissing.htm',
#  '/g/goodnews.htm',
#  '/g/goodbyegirlthe.htm',
#  '/g/grandhotel.htm',
#  '/g/greetingsfromyorkville.htm',
#  '/g/greygardens.htm',
#  '/g/grind.htm',
#  '/g/groundhogday.htm',
#  '/g/gutenbergthemusical.htm',
#  '/g/guysanddolls.htm',
#  '/g/gypsy.htm',
#  '/h/hadestown.htm',
#  '/h/hair.htm',
#  '/h/hairspray.htm',
#  '/h/hallelujahbaby.htm',
#  '/h/hamilton.htm',
#  '/h/happiestgirlintheworldthe.htm',
#  '/h/happydays.htm',
#  '/h/happyend.htm',
#  '/h/headoverheels.htm',
#  '/h/heathers.htm',
#  '/h/hedwigandtheangryinch.htm',
#  '/h/hellodolly.htm',
#  '/h/highfidelity.htm',
#  '/h/highschoolmusical.htm',
#  '/h/highschoolmusical2.htm',
#  '/h/highschoolmusical3senioryear.htm',
#  '/h/highschoolmusicalonstage.htm',
#  '/h/highsociety.htm',
#  '/h/honk.htm',
#  '/h/howthegrinchstolechristmas.htm',
#  '/h/howtosucceedinbusinesswithoutreallytrying.htm',
#  '/h/hamilton.htm',
#  '/i/idoido.htm',
#  '/i/ilovemywife.htm',
#  '/i/iloveyoubecause.htm',
#  '/i/iloveyouyoureperfectnowchange.htm',
#  '/i/ising.htm',
#  '/i/ifthen.htm',
#  '/i/illyadarling.htm',
#  '/i/intheheights.htm',
#  '/i/introusers.htm',
#  '/i/intothewoods.htm',
#  '/i/irene.htm',
#  '/i/itsonlylife.htm',
#  '/j/jacquesbrelisaliveandwellandlivinginparis.htm',
#  '/j/janeeyre.htm',
#  '/j/jekyllhyde.htm',
#  '/j/jellyslastjam.htm',
#  '/j/jennie.htm',
#  '/j/jerryspringertheopera.htm',
#  '/j/jerseyboys.htm',
#  '/j/jesuschristsuperstar.htm',
#  '/j/josephandtheamazingtechnicolordreamcoat.htm',
#  '/j/junglebook.htm',
#  '/j/justso.htm',
#  '/k/kingandithe.htm',
#  '/k/kinkyboots.htm',
#  '/k/kismet.htm',
#  '/k/kissmekate.htm',
#  '/k/kissofthespiderwoman.htm',
#  '/k/kittyskisses.htm',
#  '/l/lacageauxfolles.htm',
#  '/l/last5yearsthe.htm',
#  '/l/leaderofthepack.htm',
#  '/l/legallyblonde.htm',
#  '/l/lennon.htm',
#  '/l/lesmiserables.htm',
#  '/l/lestat.htm',
#  '/l/lilabner.htm',
#  '/l/lightinthepiazza.htm',
#  '/l/likesofusthe.htm',
#  '/l/lionking.htm',
#  '/l/littlefish.htm',
#  '/l/littlemarysunshine.htm',
#  '/l/littleme.htm',
#  '/l/littlemermaid.htm',
#  '/l/littlenightmusic.htm',
#  '/l/littleshopofhorrors.htm',
#  '/l/littlewomen.htm',
#  '/l/lizasatthepalace.htm',
#  '/l/lonestarlove.htm',
#  '/l/lordoftherings.htm',
#  '/l/loveneverdies.htm',
#  '/l/loveonline.htm',
#  '/l/lovemusik.htm',
#  '/l/luckystiff.htm',
#  '/l/lionking.htm',
#  '/m/mackmabel.htm',
#  '/m/magictreehouse.htm',
#  '/m/makemeasong.htm',
#  '/m/mame.htm',
#  '/m/mammamia.htm',
#  '/m/manoflamancha.htm',
#  '/m/manofnoimportancea.htm',
#  '/m/marchofthefalsettos.htm',
#  '/m/marguerite.htm',
#  '/m/mariechristine.htm',
#  '/m/marvelouswonderettesthe.htm',
#  '/m/marypoppins.htm',
#  '/m/matilda.htm',
#  '/m/meandjuliet.htm',
#  '/m/meandmygirl.htm',
#  '/m/menobodyknowsthe.htm',
#  '/m/meangirls.htm',
#  '/m/meetmeinstlouis.htm',
#  '/m/memphis.htm',
#  '/m/menopause.htm',
#  '/m/merrilywerollalong.htm',
#  '/m/milkandhoney.htm',
#  '/m/milliondollarquartet.htm',
#  '/m/missliberty.htm',
#  '/m/misssaigon.htm',
#  '/m/mosthappyfellathe.htm',
#  '/m/motown.htm',
#  '/m/movinout.htm',
#  '/m/mrmarktwain.htm',
#  '/m/mrpresident.htm',
#  '/m/musicmanthe.htm',
#  '/m/myfairlady.htm',
#  '/m/myfavoriteyear.htm',
#  '/m/mynamewillalwaysbealice.htm',
#  '/m/mysteryofedwindroodthe.htm',
#  '/m/mythsandhymns.htm',
#  '/n/nakedboyssinging.htm',
#  '/n/narnia.htm',
#  '/n/natashapierreandthegreatcometof1812.htm',
#  '/n/newbraina.htm',
#  '/n/newgirlintown.htm',
#  '/n/newsies.htm',
#  '/n/nexttonormal.htm',
#  '/n/niceworkifyoucangetit.htm',
#  '/n/nine.htm',
#  '/n/nostrings.htm',
#  '/n/notredamedeparis.htm',
#  '/o/oftheeising.htm',
#  '/o/ohcaptain.htm',
#  '/o/ohkay.htm',
#  '/o/oklahoma.htm',
#  '/o/oliver.htm',
#  '/o/onacleardayyoucanseeforever.htm',
#  '/o/ontherecord.htm',
#  '/o/onthetown.htm',
#  '/o/onyourfeet.htm',
#  '/o/onceonthisisland.htm',
#  '/o/onceuponamattress.htm',
#  '/o/outofthisworld.htm',
#  '/p/pacificovertures.htm',
#  '/p/paintyourwagon.htm',
#  '/p/pajamagamethe.htm',
#  '/p/paljoey.htm',
#  '/p/parade.htm',
#  '/p/passingstrange.htm',
#  '/p/passion.htm',
#  '/p/peoplevsmona.htm',
#  '/p/peterpan.htm',
#  '/p/phantomoftheoperathe.htm',
#  '/p/pipedream.htm',
#  '/p/pippin.htm',
#  '/p/piratequeenthe.htm',
#  '/p/piratesofpenzancethe.htm',
#  '/p/playon.htm',
#  '/p/pocahontas.htm',
#  '/p/prettyfaces.htm',
#  '/p/prettywoman.htm',
#  '/p/princessandthefrog.htm',
#  '/p/priscillaqueenofthedesert.htm',
#  '/p/producers.htm',
#  '/p/prom.htm',
#  '/p/promnight.htm',
#  '/p/promisespromises.htm',
#  '/p/pumpboysanddinettes.htm',
#  '/p/phantomoftheoperathe.htm',
#  '/p/prettywoman.htm',
#  '/q/quadrophenia.htm',
#  '/q/queenofthemist.htm',
#  '/q/quilters.htm',
#  '/r/radiocitychristmasspectacular.htm',
#  '/r/ragtime.htm',
#  '/r/raisin.htm',
#  '/r/redhead.htm',
#  '/r/reefermadness.htm',
#  '/r/rent.htm',
#  '/r/repothegeneticopera.htm',
#  '/r/ringoffire.htm',
#  '/r/rinkthe.htm',
#  '/r/roarofthegreasepaintthethesmellofthecrowd.htm',
#  '/r/rockofages.htm',
#  '/r/rockyhorrorshow.htm',
#  '/r/rodgersandhammersteinssouthpacific.htm',
#  '/r/roomsarockromance.htm',
#  '/r/rudeawakening.htm',
#  '/s/saladdays.htm',
#  '/s/saturdaynightfever.htm',
#  '/s/saydarling.htm',
#  '/s/scarletpimpernelthe.htm',
#  '/s/schoolofrock.htm',
#  '/s/scrooge.htm',
#  '/s/secretgardenthe.htm',
#  '/s/seewhatiwannasee.htm',
#  '/s/seesaw.htm',
#  '/s/seussical.htm',
#  '/s/sevenbridesforsevenbrothers.htm',
#  '/s/shelovesme.htm',
#  '/s/shout.htm',
#  '/s/showboat.htm',
#  '/s/shrek.htm',
#  '/s/sideshow.htm',
#  '/s/silence.htm',
#  '/s/singinintherain.htm',
#  '/s/sisteractthemusical.htm',
#  '/s/smash.htm',
#  '/s/smile.htm',
#  '/s/smokeyjoescafe.htm',
#  '/s/snoopy.htm',
#  '/s/snowwhiteandthesevendwarfs.htm',
#  '/s/solong174thstreet.htm',
#  '/s/somethingrotten.htm',
#  '/s/songdance.htm',
#  '/s/songsforanewworld.htm',
#  '/s/soundofmusicthe.htm',
#  '/s/southpacific.htm',
#  '/s/spamalot.htm',
#  '/s/specialvictimsunit.htm',
#  '/s/spidermanturnoffthedark.htm',
#  '/s/spongebobsquarepants.htm',
#  '/s/spoofodyssey.htm',
#  '/s/springawakening.htm',
#  '/s/starisborna.htm',
#  '/s/starlightexpress.htm',
#  '/s/statefair.htm',
#  '/s/steelpier.htm',
#  '/s/storyofmylifethe.htm',
#  '/s/subwaysareforsleeping.htm',
#  '/s/sugar.htm',
#  '/s/summerof42.htm',
#  '/s/summerstock.htm',
#  '/s/sundayintheparkwithgeorge.htm',
#  '/s/sunsetboulevard.htm',
#  '/s/sweeneytoddthedemonbarberoffleetstreet.htm',
#  '/s/sweetcharity.htm',
#  '/s/swing.htm',
#  '/t/taboo.htm',
#  '/t/takeflight.htm',
#  '/t/takemealong.htm',
#  '/t/taleoftwocitiesa.htm',
#  '/t/tarzan.htm',
#  '/t/tellmeonasunday.htm',
#  '/t/thatswhatkidsdo.htm',
#  '/t/thethingaboutmen.htm',
#  '/t/theyreplayingoursong.htm',
#  '/t/thoroughlymodernmillie.htm',
#  '/t/ticktickboom.htm',
#  '/t/titanic.htm',
#  '/t/titleofshow.htm',
#  '/t/toxicavengerthe.htm',
#  '/t/triumphoflove.htm',
#  '/t/twogentlemenofverona.htm',
#  '/u/unsinkablemollybrownthe.htm',
#  '/u/urinetown.htm',
#  '/v/vanities.htm',
#  '/v/verygoodeddie.htm',
#  '/v/verypottersequela.htm',
#  '/v/verypottera.htm',
#  '/v/victorvictoria.htm',
#  '/w/waitress.htm',
#  '/w/walmartopia.htm',
#  '/w/warpaint.htm',
#  '/w/waterbabies.htm',
#  '/w/wewillrockyou.htm',
#  '/w/weddingsinger.htm',
#  '/w/westsidestory.htm',
#  '/w/whitechristmas.htm',
#  '/w/whostommythe.htm',
#  '/w/wicked.htm',
#  '/w/wildparty.htm',
#  '/w/wildcat.htm',
#  '/w/willrogersfolliesthe.htm',
#  '/w/wizthe.htm',
#  '/w/wizardofozthe.htm',
#  '/w/womaninwhite.htm',
#  '/w/womenonthevergeofanervousbreakdown.htm',
#  '/w/wonderfultown.htm',
#  '/w/wonderlandalicesnewmusicaladventure.htm',
#  '/w/working.htm',
#  '/w/wicked.htm',
#  '/x/xanadu.htm',
#  '/y/yank.htm',
#  '/y/yearwithfrogandtoada.htm',
#  '/y/youreagoodmancharliebrown.htm',
#  '/y/youngfrankenstein.htm',
#  '/z/zthemaskedmusicalofzorro.htm',
#  '/z/zannadont.htm',
#  '/z/zombieprom.htm',
#  '/z/zorro.htm',
#  '/19/110intheshade.htm',
#  '/19/13.htm',
#  '/19/1776.htm',
#  '/19/25thannualputnamcountyspellingbee.htm',
#  '/19/42ndstreet.htm',
#  '/19/70girls70.htm',
#  '/19/9to5.htm']

# %%
word_titles = {}
for show_url in show_urls:
    page_html = simple_get('https://www.allmusicals.com' + show_url)
    page_soup = BeautifulSoup(page_html, 'html.parser')
    title_url = show_url[show_url.rfind('/')+1:show_url.rfind('.')]
    word_titles[title_url] = page_soup.title.text[:page_soup.title.text.index("Lyrics")-1]

# %%
word_titles
# Out:
# {'110intheshade': '110 in the Shade',
#  '13': '13',
#  '1776': '1776',
#  '25thannualputnamcountyspellingbee': '25th Annual Putnam County Spelling Bee',
#  '42ndstreet': '42nd Street',
#  '70girls70': '70, Girls, 70',
#  '9to5': '9 to 5',
#  'ace': 'Ace',
#  'acrosstheuniverse': 'Across the Universe',
#  'actthe': 'Act, The',
#  'adayinhollywoodanightintheukraine': 'A Day in Hollywood / A Night in the Ukraine',
#  'addamsfamilythe': 'Addams Family, The',
#  'addingmachine': 'Adding Machine',
#  'adriftinmacao': 'Adrift In Macao',
#  'adventuresoftomsawyerthe': 'Adventures of Tom Sawyer, The',
#  'aida': 'Aida',
#  'aintmisbehavin': "Ain't Misbehavin'",
#  'ainttooproud': "Ain't Too Proud",
#  'aladdin': 'Aladdin',
#  'alasalackzorrosback': "Alas! Alack! Zorro's Back!",
#  'allegro': 'Allegro',
#  'allshookup': 'All Shook Up',
#  'altarboyz': 'Altar Boyz',
#  'americanidiot': 'American Idiot',
#  'americaninparisan': 'American in Paris, An',
#  'americanmall': 'American Mall',
#  'anastasia': 'Anastasia',
#  'andrewlloydwebberdivas': 'Andrew Lloyd Webber Divas',
#  'annakarenina': 'Anna Karenina',
#  'annie': 'Annie',
#  'anniegetyourgun': 'Annie Get Your Gun',
#  'anyonecanwhistle': 'Anyone Can Whistle',
#  'anythinggoes': 'Anything Goes',
#  'applause': 'Applause',
#  'appletreethe': 'Apple Tree, The',
#  'arkthe': 'Ark, The',
#  'aspectsoflove': 'Aspects of Love',
#  'assassins': 'Assassins',
#  'asthousandscheer': 'As Thousands Cheer',
#  'avenueq': 'Avenue Q',
#  'babesinarms': 'Babes In Arms',
#  'baby': 'Baby',
#  'badgirls': 'Bad Girls',
#  'bajour': 'Bajour',
#  'bakerswifethe': "Baker's Wife, The",
#  'bandstand': 'Bandstand ',
#  'bandsvisit': "Band's Visit",
#  'bareapopopera': 'Bare: A Pop Opera',
#  'barkthemusical': 'Bark! The Musical',
#  'barnum': 'Barnum',
#  'batboy': 'Bat Boy',
#  'beautifulgamethe': 'Beautiful Game, The',
#  'beautifulthecaroleking': 'Beautiful: The Carole King',
#  'bellsareringing': 'Bells Are Ringing',
#  'bemorechill': 'Be More Chill',
#  'benfranklininparis': 'Ben Franklin in Paris',
#  'bernardaalba': 'Bernarda Alba',
#  'bestfootforward': 'Best Foot Forward',
#  'bestlittlewhorehouseintexasthe': 'Best Little Whorehouse in Texas, The',
#  'bestofbroadwaythe': 'Best of Broadway, The',
#  'big': 'Big',
#  'bigfish': 'Big Fish',
#  'bigriver': 'Big River',
#  'billyelliot': 'Billy Elliot',
#  'bloodbrothers': 'Blood Brothers',
#  'bombaydreams': 'Bombay Dreams',
#  'bookofmormonthe': 'Book of Mormon, The ',
#  'bounce': 'Bounce',
#  'boyfriendthe': 'Boy Friend, The',
#  'boyfromozthe': 'Boy From Oz, The',
#  'boysfromsyracusethe': 'Boys From Syracuse, The',
#  'bridgesofmadisoncountythe': 'Bridges of Madison County, The',
#  'brigadoon': 'Brigadoon',
#  'brightlightsbigcity': 'Bright Lights, Big City',
#  'bringindanoisebringindafunk': "Bring In 'Da Noise, Bring In 'Da Funk",
#  'bringiton': 'Bring It On',
#  'bronxtale': 'Bronx Tale',
#  'brooklyn': 'Brooklyn',
#  'bulletsoverbroadway': 'Bullets Over Broadway',
#  'burnthefloor': 'Burn The Floor',
#  'buskeralley': 'Busker Alley',
#  'byebyebirdie': 'Bye Bye Birdie',
#  'byjeeves': 'By Jeeves',
#  'cabaret': 'Cabaret',
#  'calamityjane': 'Calamity Jane',
#  'callmemadam': 'Call Me Madam',
#  'camelot': 'Camelot',
#  'cancan': 'Can-Can',
#  'candide': 'Candide',
#  'cannibal': 'Cannibal',
#  'carnival': 'Carnival',
#  'carolineorchange': 'Caroline, or Change',
#  'carousel': 'Carousel',
#  'catchmeifyoucan': 'Catch Me If You Can',
#  'cateredaffaira': 'Catered Affair, A',
#  'cats': 'Cats',
#  'chaplin': 'Chaplin',
#  'charlieandalgernon': 'Charlie and Algernon',
#  'charlieandthechocolatefactory': 'Charlie and the Chocolate Factory',
#  'chess': 'Chess',
#  'chessinconcertlive': 'Chess in Concert [LIVE]',
#  'chicago': 'Chicago',
#  'childrenofeden': 'Children Of Eden',
#  'childrensletterstogod': "Children's Letters to God",
#  'chittychittybangbang': 'Chitty Chitty Bang Bang',
#  'choruslinea': 'Chorus Line, A',
#  'christmascarola': 'Christmas Carol, A',
#  'cinderellasongsfromtheclassicfairytale': 'Cinderella: Songs from the Classic Fairy Tale',
#  'cityofangels': 'City Of Angels',
#  'civilwarthe': 'Civil War, The',
#  'civilwarthecompleteworkthe': 'Civil War: The Complete Work, The',
#  'classacta': 'Class Act, A',
#  'closerthanever': 'Closer Than Ever',
#  'colma': 'Colma',
#  'colorpurplethe': 'Color Purple, The',
#  'comefromaway': 'Come From Away',
#  'commentarythemusical': 'Commentary, The Musical',
#  'company': 'Company',
#  'connecticutyankeea': 'Connecticut Yankee, A',
#  'contact': 'Contact',
#  'copacabana': 'Copacabana',
#  'corpsebride': 'Corpse Bride',
#  'crazyforyou': 'Crazy For You',
#  'crybaby': 'Cry-Baby',
#  'curtains': 'Curtains',
#  'damnyankees': 'Damn Yankees',
#  'danceofthevampires': 'Dance of the Vampires',
#  'dearevanhansen': 'Dear Evan Hansen',
#  'dearworld': 'Dear World',
#  'dirtyrottenscoundrels': 'Dirty Rotten Scoundrels',
#  'disney60yearsofmusicalmagic': 'Disney: 60 Years of Musical Magic',
#  'disneysbeautyandthebeast': "Disney's Beauty And The Beast",
#  'doblackpatentleathershoesreallyreflectup': 'Do Black Patent Leather Shoes Really Reflect Up?',
#  'doihearawaltz': 'Do I Hear A Waltz?',
#  'doremi': 'Do Re Mi',
#  'dracula': 'Dracula',
#  'dreamgirls': 'Dreamgirls',
#  'drowsychaperonethe': 'Drowsy Chaperone, The',
#  'edgesasongcycle': 'Edges: A Song Cycle',
#  'elegiesasongcycle': 'Elegies: A Song Cycle',
#  'ernestinlove': 'Ernest in Love',
#  'evildead': 'Evil Dead',
#  'evita': 'Evita',
#  'facethemusic': 'Face the Music',
#  'falsettoland': 'Falsettoland',
#  'falsettos': 'Falsettos',
#  'fame': 'Fame',
#  'famebecomesme': 'Fame Becomes Me',
#  'fanny': 'Fanny',
#  'fantasticksthe': 'Fantasticks, The',
#  'fiddlerontheroof': 'Fiddler on the Roof',
#  'findingneverland': 'Finding Neverland',
#  'finiansrainbow': "Finian's Rainbow",
#  'fiorello': 'Fiorello',
#  'firstdate': 'First Date',
#  'fivecourselove': 'Five Course Love',
#  'fiveguysnamedmoe': 'Five Guys Named Moe',
#  'floratheredmenace': 'Flora The Red Menace',
#  'flowerdrumsong': 'Flower Drum Song',
#  'floydcollins': 'Floyd Collins',
#  'follies': 'Follies',
#  'footloose': 'Footloose',
#  'forbiddenbroadwaygoestorehab': 'Forbidden Broadway Goes to Rehab',
#  'forbiddenbroadwayvols14': 'Forbidden Broadway, Vols. 1-4',
#  'foreverplaid': 'Forever Plaid',
#  'fosse': 'Fosse',
#  'frankensteinanewmusical': 'Frankenstein: A New Musical',
#  'frogsthe': 'Frogs, The',
#  'frozen': 'Frozen',
#  'fullmontythe': 'Full Monty, The',
#  'funhome': 'Fun Home',
#  'funnygirl': 'Funny Girl',
#  'funnythinghappenedonthewaytotheforuma': 'Funny Thing Happened On The Way To The Forum, A',
#  'gaydivorcethe': 'Gay Divorce, The',
#  'gentlemansguidetoloveandmurdera': "Gentleman's Guide to Love and Murder, A",
#  'gentlemenpreferblondes': 'Gentlemen Prefer Blondes',
#  'georgem': 'George M!',
#  'ghostthemusical': 'Ghost the Musical',
#  'gigi': 'Gigi',
#  'gloriousonesthe': 'Glorious Ones, The',
#  'glorydays': 'Glory Days',
#  'godspell': 'Godspell',
#  'goldenboy': 'Golden Boy',
#  'gonemissing': 'Gone Missing',
#  'goodbyegirlthe': 'Goodbye Girl, The',
#  'goodnews': 'Good News',
#  'grandhotel': 'Grand Hotel',
#  'greetingsfromyorkville': 'Greetings From Yorkville',
#  'greygardens': 'Grey Gardens',
#  'grind': 'Grind',
#  'groundhogday': 'Groundhog Day',
#  'gutenbergthemusical': 'Gutenberg! The Musical!',
#  'guysanddolls': 'Guys and Dolls',
#  'gypsy': 'Gypsy',
#  'hadestown': 'Hadestown',
#  'hair': 'Hair',
#  'hairspray': 'Hairspray',
#  'hallelujahbaby': 'Hallelujah, Baby!',
#  'hamilton': 'Hamilton',
#  'happiestgirlintheworldthe': 'Happiest Girl in the World, The',
#  'happydays': 'Happy Days',
#  'happyend': 'Happy End',
#  'headoverheels': 'Head Over Heels',
#  'heathers': 'Heathers',
#  'hedwigandtheangryinch': 'Hedwig And The Angry Inch',
#  'hellodolly': 'Hello, Dolly',
#  'highfidelity': 'High Fidelity',
#  'highschoolmusical': 'High School Musical',
#  'highschoolmusical2': 'High School Musical 2',
#  'highschoolmusical3senioryear': 'High School Musical 3: Senior Year',
#  'highschoolmusicalonstage': 'High School Musical On Stage',
#  'highsociety': 'High Society',
#  'honk': 'Honk',
#  'howthegrinchstolechristmas': 'How the Grinch Stole Christmas',
#  'howtosucceedinbusinesswithoutreallytrying': 'How to Succeed in Business Without Really Trying',
#  'idoido': 'I Do! I Do!',
#  'ifthen': 'If/Then',
#  'illyadarling': 'Illya Darling',
#  'ilovemywife': 'I Love My Wife',
#  'iloveyoubecause': 'I Love You Because',
#  'iloveyouyoureperfectnowchange': "I Love You, You're Perfect, Now Change",
#  'intheheights': 'In the Heights',
#  'intothewoods': 'Into the Woods',
#  'introusers': 'In Trousers',
#  'irene': 'Irene',
#  'ising': 'I Sing',
#  'itsonlylife': "It's Only Life",
#  'jacquesbrelisaliveandwellandlivinginparis': 'Jacques Brel Is Alive and Well and Living in Paris',
#  'janeeyre': 'Jane Eyre',
#  'jekyllhyde': 'Jekyll & Hyde',
#  'jellyslastjam': "Jelly's Last Jam",
#  'jennie': 'Jennie',
#  'jerryspringertheopera': 'Jerry Springer: the Opera',
#  'jerseyboys': 'Jersey Boys',
#  'jesuschristsuperstar': 'Jesus Christ Superstar',
#  'josephandtheamazingtechnicolordreamcoat': 'Joseph And The Amazing Technicolor Dreamcoat',
#  'junglebook': 'Jungle Book',
#  'justso': 'Just So',
#  'kingandithe': 'King and I, The',
#  'kinkyboots': 'Kinky Boots',
#  'kismet': 'Kismet',
#  'kissmekate': 'Kiss Me, Kate',
#  'kissofthespiderwoman': 'Kiss Of The Spider Woman',
#  'kittyskisses': "Kitty's Kisses",
#  'lacageauxfolles': 'La Cage Aux Folles',
#  'last5yearsthe': 'Last 5 Years, The',
#  'leaderofthepack': 'Leader of the Pack',
#  'legallyblonde': 'Legally Blonde',
#  'lennon': 'Lennon',
#  'lesmiserables': 'Les Miserables',
#  'lestat': 'Lestat',
#  'lightinthepiazza': 'Light in the Piazza',
#  'likesofusthe': 'Likes of US, The',
#  'lilabner': "Li'l Abner",
#  'lionking': 'Lion King',
#  'littlefish': 'Little Fish',
#  'littlemarysunshine': 'Little Mary Sunshine',
#  'littleme': 'Little Me',
#  'littlemermaid': 'Little Mermaid',
#  'littlenightmusic': 'Little Night Music',
#  'littleshopofhorrors': 'Little Shop of Horrors',
#  'littlewomen': 'Little Women',
#  'lizasatthepalace': "Liza's at the Palace",
#  'lonestarlove': 'Lone Star Love',
#  'lordoftherings': 'Lord of the Rings',
#  'lovemusik': 'LoveMusik',
#  'loveneverdies': 'Love Never Dies',
#  'loveonline': 'Love Online',
#  'luckystiff': 'Lucky Stiff',
#  'mackmabel': 'Mack & Mabel',
#  'magictreehouse': 'Magic Tree House',
#  'makemeasong': 'Make Me A Song',
#  'mame': 'Mame',
#  'mammamia': 'Mamma Mia!',
#  'manoflamancha': 'Man of La Mancha',
#  'manofnoimportancea': 'Man of No Importance, A',
#  'marchofthefalsettos': 'March Of The Falsettos',
#  'marguerite': 'Marguerite',
#  'mariechristine': 'Marie Christine',
#  'marvelouswonderettesthe': 'Marvelous Wonderettes, The',
#  'marypoppins': 'Mary Poppins',
#  'matilda': 'Matilda',
#  'meandjuliet': 'Me and Juliet',
#  'meandmygirl': 'Me and My Girl',
#  'meangirls': 'Mean Girls',
#  'meetmeinstlouis': 'Meet Me In St. Louis',
#  'memphis': 'Memphis',
#  'menobodyknowsthe': 'Me Nobody Knows, The',
#  'menopause': 'Menopause',
#  'merrilywerollalong': 'Merrily We Roll Along',
#  'milkandhoney': 'Milk And Honey',
#  'milliondollarquartet': 'Million Dollar Quartet',
#  'missliberty': 'Miss Liberty',
#  'misssaigon': 'Miss Saigon',
#  'mosthappyfellathe': 'Most Happy Fella, The',
#  'motown': 'Motown',
#  'movinout': "Movin' Out",
#  'mrmarktwain': 'Mr. Mark Twain',
#  'mrpresident': 'Mr. President',
#  'musicmanthe': 'Music Man, The',
#  'myfairlady': 'My Fair Lady',
#  'myfavoriteyear': 'My Favorite Year',
#  'mynamewillalwaysbealice': 'My Name will always be Alice',
#  'mysteryofedwindroodthe': 'Mystery Of Edwin Drood, The',
#  'mythsandhymns': 'Myths And Hymns',
#  'nakedboyssinging': 'Naked. Boys Singing!',
#  'narnia': 'Narnia',
#  'natashapierreandthegreatcometof1812': 'Natasha, Pierre, And The Great Comet Of 1812',
#  'newbraina': 'New Brain, A',
#  'newgirlintown': 'New Girl in Town',
#  'newsies': 'Newsies',
#  'nexttonormal': 'Next to Normal',
#  'niceworkifyoucangetit': 'Nice Work If You Can Get It',
#  'nine': 'Nine',
#  'nostrings': 'No Strings',
#  'notredamedeparis': 'Notre Dame de Paris',
#  'oftheeising': 'Of Thee I Sing',
#  'ohcaptain': 'Oh Captain',
#  'ohkay': 'Oh, Kay!',
#  'oklahoma': 'Oklahoma',
#  'oliver': 'Oliver',
#  'onacleardayyoucanseeforever': 'On a Clear Day You Can See Forever',
#  'onceonthisisland': 'Once On This Island',
#  'onceuponamattress': 'Once Upon A Mattress',
#  'ontherecord': 'On the Record',
#  'onthetown': 'On The Town',
#  'onyourfeet': 'On Your Feet!',
#  'outofthisworld': 'Out Of This World',
#  'pacificovertures': 'Pacific Overtures',
#  'paintyourwagon': 'Paint Your Wagon',
#  'pajamagamethe': 'Pajama Game, The',
#  'paljoey': 'Pal Joey',
#  'parade': 'Parade',
#  'passingstrange': 'Passing Strange',
#  'passion': 'Passion',
#  'peoplevsmona': 'People vs. Mona',
#  'peterpan': 'Peter Pan',
#  'phantomoftheoperathe': 'Phantom of the Opera, The',
#  'pipedream': 'Pipe Dream',
#  'pippin': 'Pippin',
#  'piratequeenthe': 'Pirate Queen, The',
#  'piratesofpenzancethe': 'Pirates of Penzance, The',
#  'playon': 'Play On!',
#  'pocahontas': 'Pocahontas',
#  'prettyfaces': 'Pretty Faces',
#  'prettywoman': 'Pretty Woman',
#  'princessandthefrog': 'Princess and the Frog',
#  'priscillaqueenofthedesert': 'Priscilla: Queen of the Desert',
#  'producers': 'Producers',
#  'prom': 'Prom',
#  'promisespromises': 'Promises, Promises',
#  'promnight': 'Prom Night',
#  'pumpboysanddinettes': 'Pump Boys And Dinettes',
#  'quadrophenia': 'Quadrophenia ',
#  'queenofthemist': 'Queen of the Mist',
#  'quilters': 'Quilters',
#  'radiocitychristmasspectacular': 'Radio City Christmas Spectacular',
#  'ragtime': 'Ragtime',
#  'raisin': 'Raisin',
#  'redhead': 'Redhead',
#  'reefermadness': 'Reefer Madness',
#  'rent': 'Rent',
#  'repothegeneticopera': 'REPO! The Genetic Opera',
#  'ringoffire': 'Ring of Fire',
#  'rinkthe': 'Rink, The',
#  'roarofthegreasepaintthethesmellofthecrowd': 'Roar Of The Greasepaint, The - The Smell Of The Crowd',
#  'rockofages': 'Rock Of Ages',
#  'rockyhorrorshow': 'Rocky Horror Show',
#  'rodgersandhammersteinssouthpacific': "Rodgers and Hammerstein's South Pacific",
#  'roomsarockromance': 'Rooms: A Rock Romance',
#  'rudeawakening': 'Rude Awakening',
#  'saladdays': 'Salad Days',
#  'saturdaynightfever': 'Saturday Night Fever',
#  'saydarling': 'Say, Darling',
#  'scarletpimpernelthe': 'Scarlet Pimpernel, The',
#  'schoolofrock': 'School of Rock',
#  'scrooge': 'Scrooge',
#  'secretgardenthe': 'Secret Garden, The',
#  'seesaw': 'Seesaw',
#  'seewhatiwannasee': 'See What I Wanna See',
#  'seussical': 'Seussical',
#  'sevenbridesforsevenbrothers': 'Seven Brides For Seven Brothers',
#  'shelovesme': 'She Loves Me',
#  'shout': 'Shout!',
#  'showboat': 'Show Boat',
#  'shrek': 'Shrek',
#  'sideshow': 'Side Show',
#  'silence': 'Silence!',
#  'singinintherain': "Singin' In The Rain",
#  'sisteractthemusical': 'Sister Act The Musical',
#  'smash': 'Smash',
#  'smile': 'Smile',
#  'smokeyjoescafe': "Smokey Joe's Cafe",
#  'snoopy': 'Snoopy',
#  'snowwhiteandthesevendwarfs': 'Snow White And The Seven Dwarfs',
#  'solong174thstreet': 'So Long, 174th Street',
#  'somethingrotten': 'Something Rotten!',
#  'songdance': 'Song & Dance',
#  'songsforanewworld': 'Songs For A New World',
#  'soundofmusicthe': 'Sound of Music, The',
#  'southpacific': 'South Pacific',
#  'spamalot': 'Spamalot',
#  'specialvictimsunit': 'Special Victims Unit',
#  'spidermanturnoffthedark': 'Spider-Man, Turn Off the Dark',
#  'spongebobsquarepants': 'SpongeBob SquarePants',
#  'spoofodyssey': 'Spoof Odyssey',
#  'springawakening': 'Spring Awakening',
#  'starisborna': 'Star Is Born, A',
#  'starlightexpress': 'Starlight Express',
#  'statefair': 'State Fair',
#  'steelpier': 'Steel Pier',
#  'storyofmylifethe': 'Story of My Life, The',
#  'subwaysareforsleeping': 'Subways Are for Sleeping',
#  'sugar': 'Sugar',
#  'summerof42': "Summer of '42",
#  'summerstock': 'Summer Stock',
#  'sundayintheparkwithgeorge': 'Sunday in the Park With George',
#  'sunsetboulevard': 'Sunset Boulevard',
#  'sweeneytoddthedemonbarberoffleetstreet': 'Sweeney Todd: The Demon Barber of Fleet Street',
#  'sweetcharity': 'Sweet Charity',
#  'swing': 'Swing!',
#  'taboo': 'Taboo',
#  'takeflight': 'Take Flight',
#  'takemealong': 'Take Me Along',
#  'taleoftwocitiesa': 'Tale of Two Cities, A',
#  'tarzan': 'Tarzan',
#  'tellmeonasunday': 'Tell Me On A Sunday',
#  'thatswhatkidsdo': "That's What Kids Do",
#  'thethingaboutmen': 'The Thing About Men',
#  'theyreplayingoursong': "They're Playing Our Song",
#  'thoroughlymodernmillie': 'Thoroughly Modern Millie',
#  'ticktickboom': 'Tick, Tick... Boom',
#  'titanic': 'Titanic',
#  'titleofshow': 'Title Of Show',
#  'toxicavengerthe': 'Toxic Avenger, The',
#  'triumphoflove': 'Triumph Of Love',
#  'twogentlemenofverona': 'Two Gentlemen of Verona',
#  'unsinkablemollybrownthe': 'Unsinkable Molly Brown, The',
#  'urinetown': 'Urinetown',
#  'vanities': 'Vanities',
#  'verygoodeddie': 'Very Good Eddie',
#  'verypottera': 'Very Potter, A',
#  'verypottersequela': 'Very Potter Sequel, A',
#  'victorvictoria': 'Victor / Victoria',
#  'waitress': 'Waitress',
#  'walmartopia': 'Walmartopia',
#  'warpaint': 'War Paint',
#  'waterbabies': 'Water Babies',
#  'weddingsinger': 'Wedding Singer',
#  'westsidestory': 'West Side Story',
#  'wewillrockyou': 'We Will Rock You',
#  'whitechristmas': 'White Christmas',
#  'whostommythe': "Who's Tommy, The",
#  'wicked': 'Wicked',
#  'wildcat': 'Wildcat',
#  'wildparty': 'Wild Party',
#  'willrogersfolliesthe': 'Will Rogers Follies, The',
#  'wizardofozthe': 'Wizard Of Oz, The',
#  'wizthe': 'Wiz, The',
#  'womaninwhite': 'Woman In White',
#  'womenonthevergeofanervousbreakdown': 'Women on the Verge of a Nervous Breakdown',
#  'wonderfultown': 'Wonderful Town',
#  'wonderlandalicesnewmusicaladventure': "Wonderland: Alice's New Musical Adventure",
#  'working': 'Working',
#  'xanadu': 'Xanadu',
#  'yank': 'Yank!',
#  'yearwithfrogandtoada': 'Year with Frog and Toad, A',
#  'youngfrankenstein': 'Young Frankenstein',
#  'youreagoodmancharliebrown': "You're a Good Man, Charlie Brown",
#  'zannadont': "Zanna, Don't",
#  'zombieprom': 'Zombie Prom',
#  'zorro': 'Zorro',
#  'zthemaskedmusicalofzorro': 'Z, the Masked Musical of Zorro'}

# %%
descriptions = {}
for show in word_titles.keys():
    descriptions[word_titles[show]] = []
    review_html = simple_get('https://www.allmusicals.com/lyrics/' + show + '/review.htm')
    if review_html is not None:
        review_soup = BeautifulSoup(review_html, 'html.parser')
        #print(cast_soup)
        if review_soup != []:
            desc = review_soup.findAll('div', attrs = {'id':'page'})
            for s in desc[0].stripped_strings:
                descriptions[word_titles[show]].append(s)

# %%
len(descriptions)
# Out:
# 473

# %%
for key in descriptions:
    if descriptions[key] == []:
        print(key)
# Out:
# I Sing
# Prom Night
# Civil War: The Complete Work, The
# Ark, The

# %%
for key in descriptions:
    if descriptions[key] != []:
        descriptions[key] = descriptions[key][1:len(descriptions[key])-1]

# %%
for key in descriptions:
    if descriptions[key] != [] and len(descriptions[key]) > 1:
        descriptions[key] = " ".join(descriptions[key])

# %%
f = open("show_descriptions.pkl","wb")
pickle.dump(descriptions,f)
f.close()

# %%
#image scraping

# %%
import urllib.request as urllib2

import re

import os

from os.path import basename

from urllib.parse import urlsplit

from urllib.parse import urlparse

from posixpath import basename,dirname

# %%
os.mkdir('images')

# %%
for show_url in show_urls[408:]:
    url = "https://www.allmusicals.com" + show_url
    show_html = simple_get(url)
    show_soup = BeautifulSoup(show_html, 'html.parser')
    img_tags = show_soup.findAll('img', {'src':re.compile('.jpg')})

    img = str(img_tags[0])
    img = img[img.find("src=")+5:img.find(".jpg")+4]
    imgurl = "https://www.allmusicals.com" + img
    imgdata=urllib2.urlopen(imgurl).read()
    filname= 'images/'+ show_url[show_url.rfind("/")+1:show_url.rfind(".htm")] + ".jpg"
    output=open(filname,'wb')
    output.write(imgdata)
    output.close()

# %%
#Dictionary combining

# %%
word_titles
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9df0b31c47dc> in <module>()
# ----> 1 word_titles
#
# NameError: name 'word_titles' is not defined

# %%
title_to_url = {show.strip():url for url,show in word_titles.items()}

# %%
title_to_url
# Out:
# {'110 in the Shade': '110intheshade',
#  '13': '13',
#  '1776': '1776',
#  '25th Annual Putnam County Spelling Bee': '25thannualputnamcountyspellingbee',
#  '42nd Street': '42ndstreet',
#  '70, Girls, 70': '70girls70',
#  '9 to 5': '9to5',
#  'A Day in Hollywood / A Night in the Ukraine': 'adayinhollywoodanightintheukraine',
#  'Ace': 'ace',
#  'Across the Universe': 'acrosstheuniverse',
#  'Act, The': 'actthe',
#  'Addams Family, The': 'addamsfamilythe',
#  'Adding Machine': 'addingmachine',
#  'Adrift In Macao': 'adriftinmacao',
#  'Adventures of Tom Sawyer, The': 'adventuresoftomsawyerthe',
#  'Aida': 'aida',
#  "Ain't Misbehavin'": 'aintmisbehavin',
#  "Ain't Too Proud": 'ainttooproud',
#  'Aladdin': 'aladdin',
#  "Alas! Alack! Zorro's Back!": 'alasalackzorrosback',
#  'All Shook Up': 'allshookup',
#  'Allegro': 'allegro',
#  'Altar Boyz': 'altarboyz',
#  'American Idiot': 'americanidiot',
#  'American Mall': 'americanmall',
#  'American in Paris, An': 'americaninparisan',
#  'Anastasia': 'anastasia',
#  'Andrew Lloyd Webber Divas': 'andrewlloydwebberdivas',
#  'Anna Karenina': 'annakarenina',
#  'Annie': 'annie',
#  'Annie Get Your Gun': 'anniegetyourgun',
#  'Anyone Can Whistle': 'anyonecanwhistle',
#  'Anything Goes': 'anythinggoes',
#  'Applause': 'applause',
#  'Apple Tree, The': 'appletreethe',
#  'Ark, The': 'arkthe',
#  'As Thousands Cheer': 'asthousandscheer',
#  'Aspects of Love': 'aspectsoflove',
#  'Assassins': 'assassins',
#  'Avenue Q': 'avenueq',
#  'Babes In Arms': 'babesinarms',
#  'Baby': 'baby',
#  'Bad Girls': 'badgirls',
#  'Bajour': 'bajour',
#  "Baker's Wife, The": 'bakerswifethe',
#  "Band's Visit": 'bandsvisit',
#  'Bandstand': 'bandstand',
#  'Bare: A Pop Opera': 'bareapopopera',
#  'Bark! The Musical': 'barkthemusical',
#  'Barnum': 'barnum',
#  'Bat Boy': 'batboy',
#  'Be More Chill': 'bemorechill',
#  'Beautiful Game, The': 'beautifulgamethe',
#  'Beautiful: The Carole King': 'beautifulthecaroleking',
#  'Bells Are Ringing': 'bellsareringing',
#  'Ben Franklin in Paris': 'benfranklininparis',
#  'Bernarda Alba': 'bernardaalba',
#  'Best Foot Forward': 'bestfootforward',
#  'Best Little Whorehouse in Texas, The': 'bestlittlewhorehouseintexasthe',
#  'Best of Broadway, The': 'bestofbroadwaythe',
#  'Big': 'big',
#  'Big Fish': 'bigfish',
#  'Big River': 'bigriver',
#  'Billy Elliot': 'billyelliot',
#  'Blood Brothers': 'bloodbrothers',
#  'Bombay Dreams': 'bombaydreams',
#  'Book of Mormon, The': 'bookofmormonthe',
#  'Bounce': 'bounce',
#  'Boy Friend, The': 'boyfriendthe',
#  'Boy From Oz, The': 'boyfromozthe',
#  'Boys From Syracuse, The': 'boysfromsyracusethe',
#  'Bridges of Madison County, The': 'bridgesofmadisoncountythe',
#  'Brigadoon': 'brigadoon',
#  'Bright Lights, Big City': 'brightlightsbigcity',
#  "Bring In 'Da Noise, Bring In 'Da Funk": 'bringindanoisebringindafunk',
#  'Bring It On': 'bringiton',
#  'Bronx Tale': 'bronxtale',
#  'Brooklyn': 'brooklyn',
#  'Bullets Over Broadway': 'bulletsoverbroadway',
#  'Burn The Floor': 'burnthefloor',
#  'Busker Alley': 'buskeralley',
#  'By Jeeves': 'byjeeves',
#  'Bye Bye Birdie': 'byebyebirdie',
#  'Cabaret': 'cabaret',
#  'Calamity Jane': 'calamityjane',
#  'Call Me Madam': 'callmemadam',
#  'Camelot': 'camelot',
#  'Can-Can': 'cancan',
#  'Candide': 'candide',
#  'Cannibal': 'cannibal',
#  'Carnival': 'carnival',
#  'Caroline, or Change': 'carolineorchange',
#  'Carousel': 'carousel',
#  'Catch Me If You Can': 'catchmeifyoucan',
#  'Catered Affair, A': 'cateredaffaira',
#  'Cats': 'cats',
#  'Chaplin': 'chaplin',
#  'Charlie and Algernon': 'charlieandalgernon',
#  'Charlie and the Chocolate Factory': 'charlieandthechocolatefactory',
#  'Chess': 'chess',
#  'Chess in Concert [LIVE]': 'chessinconcertlive',
#  'Chicago': 'chicago',
#  'Children Of Eden': 'childrenofeden',
#  "Children's Letters to God": 'childrensletterstogod',
#  'Chitty Chitty Bang Bang': 'chittychittybangbang',
#  'Chorus Line, A': 'choruslinea',
#  'Christmas Carol, A': 'christmascarola',
#  'Cinderella: Songs from the Classic Fairy Tale': 'cinderellasongsfromtheclassicfairytale',
#  'City Of Angels': 'cityofangels',
#  'Civil War, The': 'civilwarthe',
#  'Civil War: The Complete Work, The': 'civilwarthecompleteworkthe',
#  'Class Act, A': 'classacta',
#  'Closer Than Ever': 'closerthanever',
#  'Colma': 'colma',
#  'Color Purple, The': 'colorpurplethe',
#  'Come From Away': 'comefromaway',
#  'Commentary, The Musical': 'commentarythemusical',
#  'Company': 'company',
#  'Connecticut Yankee, A': 'connecticutyankeea',
#  'Contact': 'contact',
#  'Copacabana': 'copacabana',
#  'Corpse Bride': 'corpsebride',
#  'Crazy For You': 'crazyforyou',
#  'Cry-Baby': 'crybaby',
#  'Curtains': 'curtains',
#  'Damn Yankees': 'damnyankees',
#  'Dance of the Vampires': 'danceofthevampires',
#  'Dear Evan Hansen': 'dearevanhansen',
#  'Dear World': 'dearworld',
#  'Dirty Rotten Scoundrels': 'dirtyrottenscoundrels',
#  "Disney's Beauty And The Beast": 'disneysbeautyandthebeast',
#  'Disney: 60 Years of Musical Magic': 'disney60yearsofmusicalmagic',
#  'Do Black Patent Leather Shoes Really Reflect Up?': 'doblackpatentleathershoesreallyreflectup',
#  'Do I Hear A Waltz?': 'doihearawaltz',
#  'Do Re Mi': 'doremi',
#  'Dracula': 'dracula',
#  'Dreamgirls': 'dreamgirls',
#  'Drowsy Chaperone, The': 'drowsychaperonethe',
#  'Edges: A Song Cycle': 'edgesasongcycle',
#  'Elegies: A Song Cycle': 'elegiesasongcycle',
#  'Ernest in Love': 'ernestinlove',
#  'Evil Dead': 'evildead',
#  'Evita': 'evita',
#  'Face the Music': 'facethemusic',
#  'Falsettoland': 'falsettoland',
#  'Falsettos': 'falsettos',
#  'Fame': 'fame',
#  'Fame Becomes Me': 'famebecomesme',
#  'Fanny': 'fanny',
#  'Fantasticks, The': 'fantasticksthe',
#  'Fiddler on the Roof': 'fiddlerontheroof',
#  'Finding Neverland': 'findingneverland',
#  "Finian's Rainbow": 'finiansrainbow',
#  'Fiorello': 'fiorello',
#  'First Date': 'firstdate',
#  'Five Course Love': 'fivecourselove',
#  'Five Guys Named Moe': 'fiveguysnamedmoe',
#  'Flora The Red Menace': 'floratheredmenace',
#  'Flower Drum Song': 'flowerdrumsong',
#  'Floyd Collins': 'floydcollins',
#  'Follies': 'follies',
#  'Footloose': 'footloose',
#  'Forbidden Broadway Goes to Rehab': 'forbiddenbroadwaygoestorehab',
#  'Forbidden Broadway, Vols. 1-4': 'forbiddenbroadwayvols14',
#  'Forever Plaid': 'foreverplaid',
#  'Fosse': 'fosse',
#  'Frankenstein: A New Musical': 'frankensteinanewmusical',
#  'Frogs, The': 'frogsthe',
#  'Frozen': 'frozen',
#  'Full Monty, The': 'fullmontythe',
#  'Fun Home': 'funhome',
#  'Funny Girl': 'funnygirl',
#  'Funny Thing Happened On The Way To The Forum, A': 'funnythinghappenedonthewaytotheforuma',
#  'Gay Divorce, The': 'gaydivorcethe',
#  "Gentleman's Guide to Love and Murder, A": 'gentlemansguidetoloveandmurdera',
#  'Gentlemen Prefer Blondes': 'gentlemenpreferblondes',
#  'George M!': 'georgem',
#  'Ghost the Musical': 'ghostthemusical',
#  'Gigi': 'gigi',
#  'Glorious Ones, The': 'gloriousonesthe',
#  'Glory Days': 'glorydays',
#  'Godspell': 'godspell',
#  'Golden Boy': 'goldenboy',
#  'Gone Missing': 'gonemissing',
#  'Good News': 'goodnews',
#  'Goodbye Girl, The': 'goodbyegirlthe',
#  'Grand Hotel': 'grandhotel',
#  'Greetings From Yorkville': 'greetingsfromyorkville',
#  'Grey Gardens': 'greygardens',
#  'Grind': 'grind',
#  'Groundhog Day': 'groundhogday',
#  'Gutenberg! The Musical!': 'gutenbergthemusical',
#  'Guys and Dolls': 'guysanddolls',
#  'Gypsy': 'gypsy',
#  'Hadestown': 'hadestown',
#  'Hair': 'hair',
#  'Hairspray': 'hairspray',
#  'Hallelujah, Baby!': 'hallelujahbaby',
#  'Hamilton': 'hamilton',
#  'Happiest Girl in the World, The': 'happiestgirlintheworldthe',
#  'Happy Days': 'happydays',
#  'Happy End': 'happyend',
#  'Head Over Heels': 'headoverheels',
#  'Heathers': 'heathers',
#  'Hedwig And The Angry Inch': 'hedwigandtheangryinch',
#  'Hello, Dolly': 'hellodolly',
#  'High Fidelity': 'highfidelity',
#  'High School Musical': 'highschoolmusical',
#  'High School Musical 2': 'highschoolmusical2',
#  'High School Musical 3: Senior Year': 'highschoolmusical3senioryear',
#  'High School Musical On Stage': 'highschoolmusicalonstage',
#  'High Society': 'highsociety',
#  'Honk': 'honk',
#  'How the Grinch Stole Christmas': 'howthegrinchstolechristmas',
#  'How to Succeed in Business Without Really Trying': 'howtosucceedinbusinesswithoutreallytrying',
#  'I Do! I Do!': 'idoido',
#  'I Love My Wife': 'ilovemywife',
#  'I Love You Because': 'iloveyoubecause',
#  "I Love You, You're Perfect, Now Change": 'iloveyouyoureperfectnowchange',
#  'I Sing': 'ising',
#  'If/Then': 'ifthen',
#  'Illya Darling': 'illyadarling',
#  'In Trousers': 'introusers',
#  'In the Heights': 'intheheights',
#  'Into the Woods': 'intothewoods',
#  'Irene': 'irene',
#  "It's Only Life": 'itsonlylife',
#  'Jacques Brel Is Alive and Well and Living in Paris': 'jacquesbrelisaliveandwellandlivinginparis',
#  'Jane Eyre': 'janeeyre',
#  'Jekyll & Hyde': 'jekyllhyde',
#  "Jelly's Last Jam": 'jellyslastjam',
#  'Jennie': 'jennie',
#  'Jerry Springer: the Opera': 'jerryspringertheopera',
#  'Jersey Boys': 'jerseyboys',
#  'Jesus Christ Superstar': 'jesuschristsuperstar',
#  'Joseph And The Amazing Technicolor Dreamcoat': 'josephandtheamazingtechnicolordreamcoat',
#  'Jungle Book': 'junglebook',
#  'Just So': 'justso',
#  'King and I, The': 'kingandithe',
#  'Kinky Boots': 'kinkyboots',
#  'Kismet': 'kismet',
#  'Kiss Me, Kate': 'kissmekate',
#  'Kiss Of The Spider Woman': 'kissofthespiderwoman',
#  "Kitty's Kisses": 'kittyskisses',
#  'La Cage Aux Folles': 'lacageauxfolles',
#  'Last 5 Years, The': 'last5yearsthe',
#  'Leader of the Pack': 'leaderofthepack',
#  'Legally Blonde': 'legallyblonde',
#  'Lennon': 'lennon',
#  'Les Miserables': 'lesmiserables',
#  'Lestat': 'lestat',
#  "Li'l Abner": 'lilabner',
#  'Light in the Piazza': 'lightinthepiazza',
#  'Likes of US, The': 'likesofusthe',
#  'Lion King': 'lionking',
#  'Little Fish': 'littlefish',
#  'Little Mary Sunshine': 'littlemarysunshine',
#  'Little Me': 'littleme',
#  'Little Mermaid': 'littlemermaid',
#  'Little Night Music': 'littlenightmusic',
#  'Little Shop of Horrors': 'littleshopofhorrors',
#  'Little Women': 'littlewomen',
#  "Liza's at the Palace": 'lizasatthepalace',
#  'Lone Star Love': 'lonestarlove',
#  'Lord of the Rings': 'lordoftherings',
#  'Love Never Dies': 'loveneverdies',
#  'Love Online': 'loveonline',
#  'LoveMusik': 'lovemusik',
#  'Lucky Stiff': 'luckystiff',
#  'Mack & Mabel': 'mackmabel',
#  'Magic Tree House': 'magictreehouse',
#  'Make Me A Song': 'makemeasong',
#  'Mame': 'mame',
#  'Mamma Mia!': 'mammamia',
#  'Man of La Mancha': 'manoflamancha',
#  'Man of No Importance, A': 'manofnoimportancea',
#  'March Of The Falsettos': 'marchofthefalsettos',
#  'Marguerite': 'marguerite',
#  'Marie Christine': 'mariechristine',
#  'Marvelous Wonderettes, The': 'marvelouswonderettesthe',
#  'Mary Poppins': 'marypoppins',
#  'Matilda': 'matilda',
#  'Me Nobody Knows, The': 'menobodyknowsthe',
#  'Me and Juliet': 'meandjuliet',
#  'Me and My Girl': 'meandmygirl',
#  'Mean Girls': 'meangirls',
#  'Meet Me In St. Louis': 'meetmeinstlouis',
#  'Memphis': 'memphis',
#  'Menopause': 'menopause',
#  'Merrily We Roll Along': 'merrilywerollalong',
#  'Milk And Honey': 'milkandhoney',
#  'Million Dollar Quartet': 'milliondollarquartet',
#  'Miss Liberty': 'missliberty',
#  'Miss Saigon': 'misssaigon',
#  'Most Happy Fella, The': 'mosthappyfellathe',
#  'Motown': 'motown',
#  "Movin' Out": 'movinout',
#  'Mr. Mark Twain': 'mrmarktwain',
#  'Mr. President': 'mrpresident',
#  'Music Man, The': 'musicmanthe',
#  'My Fair Lady': 'myfairlady',
#  'My Favorite Year': 'myfavoriteyear',
#  'My Name will always be Alice': 'mynamewillalwaysbealice',
#  'Mystery Of Edwin Drood, The': 'mysteryofedwindroodthe',
#  'Myths And Hymns': 'mythsandhymns',
#  'Naked. Boys Singing!': 'nakedboyssinging',
#  'Narnia': 'narnia',
#  'Natasha, Pierre, And The Great Comet Of 1812': 'natashapierreandthegreatcometof1812',
#  'New Brain, A': 'newbraina',
#  'New Girl in Town': 'newgirlintown',
#  'Newsies': 'newsies',
#  'Next to Normal': 'nexttonormal',
#  'Nice Work If You Can Get It': 'niceworkifyoucangetit',
#  'Nine': 'nine',
#  'No Strings': 'nostrings',
#  'Notre Dame de Paris': 'notredamedeparis',
#  'Of Thee I Sing': 'oftheeising',
#  'Oh Captain': 'ohcaptain',
#  'Oh, Kay!': 'ohkay',
#  'Oklahoma': 'oklahoma',
#  'Oliver': 'oliver',
#  'On The Town': 'onthetown',
#  'On Your Feet!': 'onyourfeet',
#  'On a Clear Day You Can See Forever': 'onacleardayyoucanseeforever',
#  'On the Record': 'ontherecord',
#  'Once On This Island': 'onceonthisisland',
#  'Once Upon A Mattress': 'onceuponamattress',
#  'Out Of This World': 'outofthisworld',
#  'Pacific Overtures': 'pacificovertures',
#  'Paint Your Wagon': 'paintyourwagon',
#  'Pajama Game, The': 'pajamagamethe',
#  'Pal Joey': 'paljoey',
#  'Parade': 'parade',
#  'Passing Strange': 'passingstrange',
#  'Passion': 'passion',
#  'People vs. Mona': 'peoplevsmona',
#  'Peter Pan': 'peterpan',
#  'Phantom of the Opera, The': 'phantomoftheoperathe',
#  'Pipe Dream': 'pipedream',
#  'Pippin': 'pippin',
#  'Pirate Queen, The': 'piratequeenthe',
#  'Pirates of Penzance, The': 'piratesofpenzancethe',
#  'Play On!': 'playon',
#  'Pocahontas': 'pocahontas',
#  'Pretty Faces': 'prettyfaces',
#  'Pretty Woman': 'prettywoman',
#  'Princess and the Frog': 'princessandthefrog',
#  'Priscilla: Queen of the Desert': 'priscillaqueenofthedesert',
#  'Producers': 'producers',
#  'Prom': 'prom',
#  'Prom Night': 'promnight',
#  'Promises, Promises': 'promisespromises',
#  'Pump Boys And Dinettes': 'pumpboysanddinettes',
#  'Quadrophenia': 'quadrophenia',
#  'Queen of the Mist': 'queenofthemist',
#  'Quilters': 'quilters',
#  'REPO! The Genetic Opera': 'repothegeneticopera',
#  'Radio City Christmas Spectacular': 'radiocitychristmasspectacular',
#  'Ragtime': 'ragtime',
#  'Raisin': 'raisin',
#  'Redhead': 'redhead',
#  'Reefer Madness': 'reefermadness',
#  'Rent': 'rent',
#  'Ring of Fire': 'ringoffire',
#  'Rink, The': 'rinkthe',
#  'Roar Of The Greasepaint, The - The Smell Of The Crowd': 'roarofthegreasepaintthethesmellofthecrowd',
#  'Rock Of Ages': 'rockofages',
#  'Rocky Horror Show': 'rockyhorrorshow',
#  "Rodgers and Hammerstein's South Pacific": 'rodgersandhammersteinssouthpacific',
#  'Rooms: A Rock Romance': 'roomsarockromance',
#  'Rude Awakening': 'rudeawakening',
#  'Salad Days': 'saladdays',
#  'Saturday Night Fever': 'saturdaynightfever',
#  'Say, Darling': 'saydarling',
#  'Scarlet Pimpernel, The': 'scarletpimpernelthe',
#  'School of Rock': 'schoolofrock',
#  'Scrooge': 'scrooge',
#  'Secret Garden, The': 'secretgardenthe',
#  'See What I Wanna See': 'seewhatiwannasee',
#  'Seesaw': 'seesaw',
#  'Seussical': 'seussical',
#  'Seven Brides For Seven Brothers': 'sevenbridesforsevenbrothers',
#  'She Loves Me': 'shelovesme',
#  'Shout!': 'shout',
#  'Show Boat': 'showboat',
#  'Shrek': 'shrek',
#  'Side Show': 'sideshow',
#  'Silence!': 'silence',
#  "Singin' In The Rain": 'singinintherain',
#  'Sister Act The Musical': 'sisteractthemusical',
#  'Smash': 'smash',
#  'Smile': 'smile',
#  "Smokey Joe's Cafe": 'smokeyjoescafe',
#  'Snoopy': 'snoopy',
#  'Snow White And The Seven Dwarfs': 'snowwhiteandthesevendwarfs',
#  'So Long, 174th Street': 'solong174thstreet',
#  'Something Rotten!': 'somethingrotten',
#  'Song & Dance': 'songdance',
#  'Songs For A New World': 'songsforanewworld',
#  'Sound of Music, The': 'soundofmusicthe',
#  'South Pacific': 'southpacific',
#  'Spamalot': 'spamalot',
#  'Special Victims Unit': 'specialvictimsunit',
#  'Spider-Man, Turn Off the Dark': 'spidermanturnoffthedark',
#  'SpongeBob SquarePants': 'spongebobsquarepants',
#  'Spoof Odyssey': 'spoofodyssey',
#  'Spring Awakening': 'springawakening',
#  'Star Is Born, A': 'starisborna',
#  'Starlight Express': 'starlightexpress',
#  'State Fair': 'statefair',
#  'Steel Pier': 'steelpier',
#  'Story of My Life, The': 'storyofmylifethe',
#  'Subways Are for Sleeping': 'subwaysareforsleeping',
#  'Sugar': 'sugar',
#  'Summer Stock': 'summerstock',
#  "Summer of '42": 'summerof42',
#  'Sunday in the Park With George': 'sundayintheparkwithgeorge',
#  'Sunset Boulevard': 'sunsetboulevard',
#  'Sweeney Todd: The Demon Barber of Fleet Street': 'sweeneytoddthedemonbarberoffleetstreet',
#  'Sweet Charity': 'sweetcharity',
#  'Swing!': 'swing',
#  'Taboo': 'taboo',
#  'Take Flight': 'takeflight',
#  'Take Me Along': 'takemealong',
#  'Tale of Two Cities, A': 'taleoftwocitiesa',
#  'Tarzan': 'tarzan',
#  'Tell Me On A Sunday': 'tellmeonasunday',
#  "That's What Kids Do": 'thatswhatkidsdo',
#  'The Thing About Men': 'thethingaboutmen',
#  "They're Playing Our Song": 'theyreplayingoursong',
#  'Thoroughly Modern Millie': 'thoroughlymodernmillie',
#  'Tick, Tick... Boom': 'ticktickboom',
#  'Titanic': 'titanic',
#  'Title Of Show': 'titleofshow',
#  'Toxic Avenger, The': 'toxicavengerthe',
#  'Triumph Of Love': 'triumphoflove',
#  'Two Gentlemen of Verona': 'twogentlemenofverona',
#  'Unsinkable Molly Brown, The': 'unsinkablemollybrownthe',
#  'Urinetown': 'urinetown',
#  'Vanities': 'vanities',
#  'Very Good Eddie': 'verygoodeddie',
#  'Very Potter Sequel, A': 'verypottersequela',
#  'Very Potter, A': 'verypottera',
#  'Victor / Victoria': 'victorvictoria',
#  'Waitress': 'waitress',
#  'Walmartopia': 'walmartopia',
#  'War Paint': 'warpaint',
#  'Water Babies': 'waterbabies',
#  'We Will Rock You': 'wewillrockyou',
#  'Wedding Singer': 'weddingsinger',
#  'West Side Story': 'westsidestory',
#  'White Christmas': 'whitechristmas',
#  "Who's Tommy, The": 'whostommythe',
#  'Wicked': 'wicked',
#  'Wild Party': 'wildparty',
#  'Wildcat': 'wildcat',
#  'Will Rogers Follies, The': 'willrogersfolliesthe',
#  'Wiz, The': 'wizthe',
#  'Wizard Of Oz, The': 'wizardofozthe',
#  'Woman In White': 'womaninwhite',
#  'Women on the Verge of a Nervous Breakdown': 'womenonthevergeofanervousbreakdown',
#  'Wonderful Town': 'wonderfultown',
#  "Wonderland: Alice's New Musical Adventure": 'wonderlandalicesnewmusicaladventure',
#  'Working': 'working',
#  'Xanadu': 'xanadu',
#  'Yank!': 'yank',
#  'Year with Frog and Toad, A': 'yearwithfrogandtoada',
#  "You're a Good Man, Charlie Brown": 'youreagoodmancharliebrown',
#  'Young Frankenstein': 'youngfrankenstein',
#  'Z, the Masked Musical of Zorro': 'zthemaskedmusicalofzorro',
#  "Zanna, Don't": 'zannadont',
#  'Zombie Prom': 'zombieprom',
#  'Zorro': 'zorro'}

# %%
bd = pickle.load(open('broadway_lyrics_v4.pkl', 'rb'))
descs = pickle.load(open('show_descriptions.pkl', 'rb'))

# %%
descs2 = {}
for key in descs:
    descs2[key.strip()] = descs[key]

# %%
for key in bd:
    bd[key]['description'] = descs2[key]
    bd[key]['img_name'] = 'app/static/images/' + title_to_url[key] + '.jpg'

# %%
bd['Dear Evan Hansen']
# Out:
# {'composer': 'Benj Pasek, Justin Paul',
#  'currently_playing': True,
#  'description': 'Watching “Dear Evan Hansen,” now playing at Off Broadway’s Second Stage Theater, is like falling down a rabbit hole that leads back to high school. Steven Levenson’s book for this bittersweet musical captures both the humor and the pathos of a hopeless misfit (played to perfection by Ben Platt) who achieves popularity through no fault of his own. And not since “Next to Normal” has a score (by Benj Pask and Justin Paul) tapped so deeply into the psyches of its troubled characters. Credit director Michael Greif, who also directed the original production at Arena Stage, for the sensitive tone of comic gravitas. Although he’s made it to senior year, Evan Hansen (Platt) suffers from the kind of debilitating anxiety that demands regular shrink visits and many pills. Platt (who appears as Benji in both “Pitch Perfect” movies) gives a carefully choreographed physical performance that makes the kid’s discomfort painfully clear. His shoulders slump, his chest caves into his backbone, his whole body is wracked with physical and vocal tics. Under the insightful direction of Greif (who performed the same services in “Next to Normal”), Platt goes beyond physical specificity to get under Evan’s itchy skin and unsettled mind. And the introspective, gentle score by Benj Pasek and Justin Paul becomes the language of his troubled thoughts and unspoken yearnings. Strictly speaking, Evan isn’t exactly a loner. He’s alone and lonely, and too self-conscious to make any friends, aside from cynical, smart -mouthed Jared (Will Roland, who was himself probably a high school brainiac). Book writer Levenson has given Evan the funniest and most pathetic symbol of teenage loneliness — someone so unpopular, he can’t get anyone to sign the cast on his broken arm. Evan’s mom, Heidi (in a warm performance by Rachel Ray Jones), is a caring mother. But she works long hours as a nurse’s aide while going to school at night to become a paralegal. To her credit, she makes sure that her son takes his meds and sees his shrink, who has given him the ego-building task of writing himself a chin-up letter every day. “Sincerely, Me,” a sweetly wry song about these back-patting letters, finds Evan alone on a dark stage, bombarded by visual cues from the social media sites that he and his classmates live by. The artsy set of moving scrims crawling with these bits of words and scraps of thought is the work of David Korins. Peter Nigrini did the fine projections, in conjunction with Japhy Weideman on lighting. But Evan can’t put his heart into these letters to himself, and by the end of the song, he’s thoroughly depressed. “Would anybody even notice if I disappear?” As it turns out, the message of this touching show answers that cri de coeur in the lyric of a song: “No one deserves to disappear.”  No matter how lonely you are, how lost, “You are not alone / You will be found.” In a twist of fate (and plot), one of Evan’s discarded letters is picked up by Connor Murphy (a terrific turn from Mike Faist). Connor is the  brother of Zoe (Laura Dreyfuss, smart as well as sensitive), the object of Evan’s hopeless crush. Connor is also a very troubled kid, who wears his hair long and messy and dresses in a Goth style that Jared flippantly describes as “school shooter chic.” When Connor commits suicide with the letter still in his pocket, everyone takes it as a suicide note, jumping to the conclusion that he and Evan were great friends. Invisible to the entire student body until this dramatic development, Evan suddenly finds himself in the spotlight. The students set up a webpage to honor their “friend” and collect money for a memorial. “Connor’s being dead is the best thing that ever happened to you,” snaps snippy Alana Beck (Kristolyn Lloyd, nice and sassy). In his agonizing self-consciousness, Evan is unable to make it clear to Connor’s parents (given painfully realistic performances by Jennifer Laura Thompson and John Dossett) that he and their son barely knew one a ...
#  'img_name': 'app/static/images/dearevanhansen.jpg',
#  'lyrics': ['Anybody Have a Map?',
#   'HEIDI:',
#   'Another stellar conversation for the scrapbook',
#   "Another stumble as I'm reaching for the right thing to say",
#   "It's a mystery at best",
#   'And with every second - second guessed',
#   'The answers feel lightyears away',
#   "See it used to be you'd come to me and solve all the problems",
#   'I could scare off any monster',
#   'Find Waldo every time',
#   'It was Super Mom to the rescue',
#   'You thought I knew it all',
#   'But I somehow went from bounding over buildings',
#   'To searching in the dark',
#   'As you became this total question mark',
#   'So...',
#   'So, does anybody have a map?',
#   'Anybody maybe happen to know how the hell to do this?',
#   "I don't know if you can tell",
#   'But this is me just pretending to know',
#   "So where's the map?",
#   'I need a clue',
#   "'Cause the scary truth is",
#   "I'm flying blind",
#   "I'm making this up as I go",
#   'CYNTHIA:',
#   'Another masterful attempt ends with disaster',
#   'Pour another cup of coffee',
#   'Watch it all crash and burn',
#   "It's a puzzle",
#   "It's a maze",
#   "I've tried to steer through it a million ways",
#   'But, each day is another wrong turn',
#   'Is there a class that I can take to learn your language?',
#   "'Cause I am trying to get with it",
#   'I use Google as a verb',
#   "Somebody come to the rescue before I'm too far gone",
#   'BOTH:',
#   'Does anybody have a map?',
#   'Anybody maybe happen to know how the hell to do this?',
#   "I don't know if you can tell",
#   'But this is me just pretending to know',
#   "So where's the map?",
#   'I need a clue',
#   "'Cause the scary truth is",
#   'CYNTHIA:',
#   "I'm flying blind (I'm flying blind)",
#   "I'm flying blind (I'm flying blind)",
#   'BOTH:',
#   "I'm flying blind",
#   "And I'm making this up as I go",
#   'As I go',
#   'Last Update: November, 23rd 2016',
#   'Waving Through a Window',
#   "I've learned to slam on the brake",
#   'Before I even turn the key',
#   'Before I make the mistake',
#   'Before I lead with the worst of me',
#   'Give them no reason to stare',
#   'No slipping up if you slip away',
#   "So I've got nothing to share",
#   'No, I got nothing to say',
#   'Step out, step out of the sun',
#   'If you keep getting burned',
#   'Step out, step out of the sun',
#   "Because you've learned, because you've learned",
#   'On the outside always looking in',
#   "Will I ever be more than I've always been?",
#   "'cause I'm tap, tap, tapping on the glass",
#   "I'm waving through a window",
#   'I try to speak, but nobody can hear',
#   'So I wait around for an answer to appear',
#   "While I'm watch, watch, watching people pass",
#   "I'm waving through a window",
#   'Oh, can anybody see, is anybody waving',
#   'Back at me?',
#   'We start with stars in our eyes',
#   'We start believing that we belong',
#   "But every sun doesn't rise",
#   'And no one tells you where you went wrong',
#   'Step out, step out of the sun',
#   'If you keep getting burned',
#   'Step out, step out of the sun',
#   "Because you've learned, because you've learned",
#   'On the outside always looking in',
#   "Will I ever be more than I've always been?",
#   "'cause I'm tap, tap, tapping on the glass",
#   'Waving through a window',
#   'I try to speak, but nobody can hear',
#   'So I wait around for an answer to appear',
#   "While I'm watch, watch, watching people pass",
#   'Waving through a window',
#   'Oh, can anybody see, is anybody waving?',
#   "When you're falling in a forest and there's nobody around",
#   'Do you ever really crash, or even make a sound',
#   "When you're falling in a forest and there's nobody around",
#   'Do you ever really crash, or even make a sound',
#   "When you're falling in a forest and there's nobody around",
#   'Do you ever really crash, or even make a sound',
#   "When you're falling in a forest and there's nobody around",
#   'Do you ever really crash, or even make a sound',
#   'Did I even make a sound',
#   'Did I even make a sound',
#   "It's like I never made a sound",
#   'Will I ever make a sound?',
#   'On the outside always looking in',
#   "Will I ever be more than I've always been",
#   "'cause I'm tap, tap, tapping on the glass",
#   'Waving through a window',
#   'I try to speak',
#   'But nobody can hear',
#   'So I wait around for an answer to appear',
#   "While I'm watch, watch, watching people pass",
#   'Waving through a window',
#   'Can anybody see, is anybody waving back at me?',
#   'Oooh, is anybody waving',
#   'Waving, waving, whoa-oh, whoa-oh-oh-oh',
#   'Last Update: November, 23rd 2016',
#   'For Forever',
#   'EVAN:',
#   'End of May or Early June',
#   'This picture perfect afternoon we shared',
#   'Drive the winding country road',
#   'Grab a scoop at A La Mode',
#   "And then we're there",
#   "An open field that's framed with trees",
#   'We pick a spot and shoot the breeze',
#   'Like buddies do',
#   'Quoting songs by our favorite bands',
#   'Telling jokes no one understands',
#   'Except us two',
#   'And we talk and take in the view',
#   'All we see is sky for forever',
#   'Let the world pass by for forever',
#   'Feels like we could go on for forever this way',
#   'Two friends on a perfect day',
#   'We walk a while and we talk about',
#   "The things we'll do when we get out of school",
#   'Bike the Appalachian trail or',
#   'Write a book',
#   'Or learn to sail',
#   "Wouldn't that be cool",
#   "There's nothing that we can't discuss",
#   'Like girls we wish would notice us but never do',
#   'He looks around and says to me',
#   '"There\'s nowhere else I\'d rather be"',
#   'I say "me too"',
#   'And we talk and take in the view',
#   'We just talk and take in the view',
#   'All we see is sky for forever',
#   'Let the world pass by for forever',
#   'Feels like we could go on for forever this way',
#   'This way',
#   'All we see is light for forever',
#   "'Cause the sun shines bright for forever",
#   'Life will be all right for forever this way',
#   'Two friends on a perfect day',
#   'And there he goes',
#   'Racing toward the tallest tree',
#   'From far across the yellow field I hear him calling "follow me"',
#   'And there we go',
#   'Wondering how the world might look from up so high',
#   'One foot after the other',
#   'One branch then to another',
#   'I climb higher and higher',
#   'I climb until the entire',
#   'Sun shines on my face',
#   'And I suddenly feel the branch give way',
#   "I'm on the ground",
#   'My arm goes numb',
#   'I look around',
#   'And I see him coming to get me',
#   "He's coming to get me",
#   "And everything's okay",
#   'All we see is sky for forever',
#   'Let the world pass by for forever',
#   'Buddy, you and I for forever this way',
#   'This way',
#   'All we see is light',
#   "'cuz the sun shines bright",
#   'Life will be all right for forever this way',
#   'Two friends',
#   'True friends',
#   'On a perfect day',
#   'Last Update: November, 23rd 2016',
#   'Sincerely, Me',
#   'CONNOR:',
#   'Dear Evan Hansen,',
#   "We've been way too out of touch",
#   "Things have been crazy and it sucks that we don't talk that much",
#   'I should tell you that I think of you each night',
#   'I rub my nipples and start moaning with delight',
#   'EVAN: (spoken) Why would you write that?',
#   "JARED: (spoken) I'm just trying to tell the truth",
#   'EVAN:',
#   "(spoken) You know what? If you aren't going to take this seriously...",
#   'JARED: (spoken) Okay you need to calm yourself!',
#   'EVAN: (spoken) This has to be perfect, okay?',
#   'The emails have to prove that we were actually friends.',
#   "They've got to be completely realistic",
#   'JARED: (spoken) There is nothing unrealistic about the love that one man feels for another.',
#   "EVAN: (spoken) Let's go back.",
#   "JARED: (spoken) In fact, it's something quite beautiful.",
#   "EVAN: (spoken) Let's go back Jared!",
#   "CONNOR: I've gotta tell you life without you has been hard",
#   'JARED: (spoken) Hard?',
#   'CONNOR: Has been bad',
#   'JARED: (spoken) Bad?',
#   'CONNOR: Has been rough',
#   'JARED: (spoken) Lame!',
#   'CONNOR: And I miss talking about life and other stuff',
#   'JARED: (spoken) Very specific',
#   'EVAN: (spoken) Shut up',
#   'CONNOR: I like my parents',
#   'JARED: (spoken) Who says that?',
#   'CONNOR:',
#   'I love my parents',
#   "But each day's another fight",
#   'If I stop smoking drugs then everything might be alright',
#   'JARED: (spoken) Smoking drugs',
#   'EVAN: (spoken) Just fix it!',
#   "JARED: (spoken) This isn't realistic at all! It doesn't even sound like Connor!",
#   'EVAN: (spoken) Well I want to show that I was a good friend,',
#   "Y'know? That I was trying to help him",
#   'JARED: (spoken) You are just cute as a freaking button',
#   'CONNOR: If I stop smoking crack',
#   'EVAN: (spoken) Crack?!',
#   'CONNOR:',
#   'If I stop smoking pot then everything might be alright',
#   "I'll take your advice",
#   "I'll try to be more nice",
#   "I'll turn it around",
#   'Wait and see',
#   'It’s all that it takes',
#   'Is a little reinvention',
#   'It’s easy to change if you give it your attention',
#   'All you gotta do is just believe you can be who you want',
#   'to be sincerely, me',
#   'JARED: (spoken) Are we done yet?',
#   "EVAN: (spoken) Well I mean I can't just show them one email",
#   'JARED: (spoken) Okay, please stop hyperventilating',
#   "EVAN: (spoken) I'm not hyperventilating",
#   "JARED: (spoken) You're having considerable trouble breathing",
#   "EVAN: (spoken) I'm having no trouble breathing",
#   'JARED: (spoken) Do you need a paper bag to breath into?',
#   "EVAN: (spoken) I'm not hyperventilating!",
#   'EVAN: (sung)',
#   'Dear Connor Murphy,',
#   "Yes I've also missed our talks",
#   'Stop doing drugs',
#   'Just try to take deep breaths and go on walks',
#   "I'm sending pictures of the most amazing trees",
#   'JARED: (spoken) No!',
#   "EVAN: You'll be obsessed with all my forest expertise",
#   'JARED: (spoken) Ridiculous!',
#   'EVAN:',
#   "Dude I'm proud of you",
#   'Just keep pushing through',
#   "You're turning around",
#   'I can see',
#   'CONNOR: Just wait and see',
#   'ALL:',
#   'It’s all that it takes',
#   'Is a little reinvention',
#   'It’s easy to change if you give it your attention',
#   'All you gotta do is just believe you can be who you want to be sincerely, me',
#   "CONNOR: My sister's hot",
#   'EVAN: (spoken) What the hell?',
#   'JARED: (spoken) My bad',
#   'CONNOR: Dear Evan Hansen, thanks for every note you send',
#   "EVAN: Dear Connor Murphy, I'm just glad to be your friend",
#   'EVAN & CONNOR: Our friendship goes beyond your average kind of bond',
#   "But not because we're Gay",
#   "No not because we're gay",
#   "We're close, but not that way",
#   'The only man that I love is my dad',
#   'CONNOR: Well anyway',
#   "EVAN: You're getting better everyday",
#   "CONNOR: I'm getting better everyday",
#   "EVAN & CONNOR: We're getting better everyday",
#   'ALL: Hey hey hey hey!',
#   'It’s all that it takes',
#   'Is a little reinvention',
#   'It’s easy to change if you give it your attention',
#   'All you gotta do is just believe you can be who you want to be sincerely,',
#   'Miss you dearly',
#   'Sincerely Me',
#   'Sincerely Me',
#   'Sincerely Me',
#   'Sincerely Me',
#   'Last Update: November, 23rd 2016',
#   'Requiem',
#   'ZOE:',
#   'Why should I play this game of pretend?',
#   'Remembering through a secondhand sorrow?',
#   'Such a great son and wonderful friend',
#   "Oh don't the tears just pour",
#   'I can curl up and hide in my room',
#   'There in my bed still sobbing tomorrow',
#   'I could give in to all of the gloom',
#   'But tell me, tell me what for',
#   'Why should I have a heavy heart?',
#   'Why should I start to break in pieces?',
#   'Why should I go and fall apart for you?',
#   'Why should I play the grieving girl and',
#   'Lie saying that I miss you',
#   'And that my world has gone dark without your light',
#   'I will sing no requiem tonight',
#   "LARRY: (spoken) I'm going to bed",
#   'CYNTHIA: (spoken) Come sit with me',
#   'LARRY: Cynthia',
#   'CYNTHIA: For five minutes?',
#   "LARRY: I'm exhausted",
#   "CYNTHIA: You know Larry, at some point you're going to have to start-",
#   "LARRY: Not tonight. Please. I'll leave the light on for you.",
#   'LARRY: (sung)',
#   'I gave you the world, you threw it away,',
#   'leaving these broken pieces behind you',
#   'Everything wasted, nothing to say',
#   'So I can sing no requiem',
#   'CYNTHIA:',
#   'I hear your voice, feel you near',
#   'Within these words I finally find you',
#   'And now that I know that you are still here',
#   'I will sing no requiem tonight',
#   'ZOE & LARRY: Why should I have a heavy heart?',
#   'ZOE:',
#   "Why should I say I'll keep you with me?",
#   'Why should I go and fall apart for you?',
#   'Why should I play the grieving girl and lie saying that I miss you',
#   'And that my world has gone dark without your light',
#   'I will sing no requiem',
#   'Tonight',
#   "'Cuz when the villains fall, the kingdoms never weep",
#   'No one lights a candle to remember',
#   'No, no one mourns at all',
#   'They lay them to sleep',
#   "So don't tell me that I didn't have it right",
#   "Don't tell me that it wasn't black and white",
#   "After all you've put me through, don't say it wasn't true",
#   'That you were not the monster that I knew,',
#   "'Cuz I cannot play the grieving girl and lie",
#   'Saying that I miss you and that my world has gone dark',
#   'LARRY: I will sing no requiem',
#   'CYNTHIA: I will sing no requiem',
#   'ZOE: I will sing no requiem tonight',
#   'Last Update: November, 23rd 2016',
#   'If I Could Tell Her',
#   'EVAN:',
#   'He said',
#   "There's nothing like your smile",
#   'Sort of subtle and perfect and real',
#   'He said',
#   'You never knew how wonderful',
#   'That smile could make someone feel',
#   'And he knew',
#   'Whenever you get bored',
#   'You scribble stars on the cuffs of your jeans',
#   'And he noticed',
#   'That you still fill out the quizzes',
#   'that they put in those teen magazines',
#   'But he kept it all inside his head',
#   'What he saw he left unsaid',
#   'And though he wanted to',
#   "He couldn't talk to you",
#   "He couldn't find the way",
#   'But he would always say',
#   'If I could tell her',
#   'Tell her everything I see',
#   'If I could tell her',
#   "How she's everything to me",
#   "But we're a million worlds apart",
#   "And I don't know how I would even start",
#   'If I could tell her',
#   'If I could tell her',
#   'ZOE: (spoken) Did he say anything else?',
#   'EVAN: (spoken) About you?',
#   "ZOE: Never mind, I don't really care",
#   'EVAN: (spoken) No, no, no, he said so many things,',
#   "I'm just trying to remember the best ones.",
#   'EVAN: He thought',
#   'You looked really pretty, er-',
#   'It looked pretty cool when you put indigo streaks in your hair',
#   'ZOE: (spoken) He did?!',
#   'EVAN: And he wondered how you learned to dance',
#   "Like all the rest of the world isn't there",
#   'But he kept it all inside his head',
#   'What he saw he left unsaid',
#   'If I could tell her',
#   'Tell her everything I see',
#   'If I could tell her',
#   "How she's everything to me",
#   "EVAN & ZOE: But we're a million worlds apart",
#   "EVAN: And I don't know how I would even start if I could tell her",
#   'If I could tell her',
#   'But what do you do',
#   "When there's this great divide",
#   'ZOE: He just seemed so far away',
#   'EVAN:',
#   'And what do you do',
#   'When the distance is too wide',
#   "ZOE: I think I don't know anything",
#   'EVAN: And how do you say I love you, I love you, I love you, I love you',
#   "But we're a million worlds apart",
#   "And I don't know how I would even start",
#   'If I could tell her',
#   'If I could',
#   'Last Update: November, 23rd 2016',
#   'Disappear',
#   'CONNOR:',
#   'Guys like you and me',
#   "We're just the losers",
#   'And we keep waiting to be seen, right?',
#   'And no one seems to care',
#   "Or stops to notice that we're there",
#   'So we get lost in the in between',
#   'But if you can somehow keep them thinking of him',
#   'And make me more than an abandoned memory',
#   'That means we matter too',
#   'It means someone will see that you are there',
#   'No one deserves to be forgotten',
#   'No one deserves to fade away',
#   'No one should come and go',
#   'And have no one know he was ever even here',
#   'No one deserves to disappear',
#   'To disappear',
#   'Disappear',
#   "It's true",
#   "But even if you've always been that",
#   'Barely in the background kind of guy',
#   'EVAN: You still matter',
#   "CONNOR: And even if you're somebody who can't escape the feeling",
#   "that the world's past you by",
#   'EVAN: You still matter',
#   'CONNOR:',
#   'If you never get around to doing some remarkable thing',
#   "That doesn't mean that you're not worth remembering",
#   'But the people who need to know',
#   'EVAN: They need to know',
#   'CONNOR: You need to know',
#   "EVAN: I'll show them",
#   'CONNOR: That no one deserves to be forgotten',
#   'EVAN:',
#   'No one deserves to be forgotten',
#   'No one deserves to fade away, to fade away',
#   'EVAN & CONNOR:',
#   'No one should flicker out',
#   'Or have any doubt that it matters that they are here',
#   'EVAN: No one deserves',
#   'CONNOR: No one deserves',
#   'EVAN & CONNOR: To disappear, to disappear, to disappear',
#   'CONNOR:',
#   "When you're falling in a forest and there's nobody around",
#   'All you want is somebody to find you',
#   "When you're falling in a forest",
#   'And when you hit the ground',
#   'All you need is somebody to find you',
#   'EVAN: No one deserves to be forgotten',
#   'EVAN, ALANA & JARED: No one deserves to fade away',
#   'CYNTHIA: No one deserves to be forgotten',
#   'EVAN, ALANA, JARED & CYNTHIA:',
#   'No one deserves to be forgotten',
#   'No one should flicker out or have any doubt',
#   'That it matters that they are here',
#   'No one deserves to disappear',
#   'To disappear',
#   'To Disappear',
#   'No one deserves, no one deserves, no one deserves to be forgotten',
#   'No one deserves to disappear',
#   'Disappear',
#   'Last Update: November, 23rd 2016',
#   'You Will Be Found',
#   'So maybe let that feeling wash away',
#   'Maybe there’s a reason to believe you’ll be okay',
#   '‘Cuz when you don’t feel strong enough to stand',
#   'You can reach out your hand',
#   'And oh, someone will coming running',
#   'And I know, they’ll take you home',
#   'Even when the dark comes crashing through',
#   'when you need a friend to carry you',
#   'when you’re broken on the ground',
#   'You will be found',
#   'So let the sun come streaming in',
#   'Cuz you’ll reach up and you’ll rise again',
#   'Lift your head off the ground and look around',
#   'You will be found',
#   'You will be found',
#   'You will be found',
#   'You will be found',
#   'There’s a place where we don’t have to be alone',
#   'Every time that you call out',
#   'You’re a little less alone',
#   'If you only say the word',
#   'Across the silence',
#   'Your voice is heard',
#   'Even when the dark comes crashing through',
#   'When you need a friend to carry you',
#   'When you’re broken on the ground',
#   'You will be found',
#   'So let the sun coming streaming in',
#   'Cuz you’ll reach up and you’ll rise again',
#   'If you only look around',
#   'You will be found',
#   'You will be found',
#   'You will be found',
#   'Out of the shadows, morning is breaking',
#   'All is new, all is new',
#   'Suddenly I see that',
#   'All is new, all is new',
#   'You are not alone',
#   'You are not alone',
#   'You are not alone',
#   'You are not alone',
#   'You are not alone',
#   'You are not alone',
#   'Even when the dark comes crashing through',
#   'And you need someone to carry you',
#   'When you’re broken on the ground',
#   'You will be found',
#   'When the sun comes streaming in',
#   'You’ll reach up and you’ll rise again',
#   'If you only look around',
#   'You will be found',
#   'You will be found',
#   'You will be found',
#   'Last Update: November, 23rd 2016',
#   'Sincerely, Me (Reprise)',
#   'CONNOR:',
#   'Dear Evan Hansen',
#   'Life at rehab is all right',
#   'I like the yoga',
#   'And the sharing circles every night',
#   'But dude, these stories sometimes scare you half to death',
#   'So many people end up sucking dick for meth',
#   'JARED: Heh, heh, heh',
#   'CONNOR:',
#   "And one more thing, that's worth mentioning",
#   'That guy from our school',
#   'JARED:',
#   'Jared Kleinman?',
#   'CONNOR:',
#   'Yes, the insanely cool Jared Kleinman',
#   'I think we should start to make him part of this awesome friendship we have',
#   'JARED & CONNOR:',
#   'A part of this awesome friend we have',
#   'This adorably heartwarming friendship we have',
#   'Hey, hey, hey',
#   "'cuz all that it takes is a little--",
#   'EVAN: (spoken) No, obviously not',
#   'Last Update: November, 23rd 2016',
#   'To Break In A Glove',
#   'LARRY:',
#   'No one will tell you how to really do it right',
#   "That's a secret method only known to very few",
#   'So if you need some pointers, just in case you might',
#   'Well, then, maybe I could show you what to do',
#   'LARRY: (spoken) Shaving cream',
#   'EVAN: (spoken) Shaving cream?',
#   'LARRY:',
#   'You rub that in for about five minutes',
#   'And then you tie it all up in rubber bands',
#   'Put it under your mattress, and sleep on it',
#   'And then the next day, you repeat',
#   'And you gotta do it for at least a week, every day, consistently',
#   'LARRY: (sung)',
#   "And though this method isn't easy",
#   'Every second that you spend is gonna pay off',
#   "It'll pay off in the end",
#   'It just takes a little patience',
#   'Takes a little time',
#   'A little perseverance',
#   'A little uphill climb',
#   "You might not think it's worth it",
#   'You might begin to doubt',
#   "But you can't take any shortcuts",
#   'You gotta stick it out',
#   "And it's the hard way, but it's the right way",
#   'The right way to break in a glove',
#   'LARRY: (spoken)',
#   'But nowadays, with your generation',
#   "I hate to say it, but it's all about instant gratification",
#   'Who wants to read a book when you can read the Facebook instead?',
#   'EVAN: (spoken) Totally',
#   'LARRY: (spoken)',
#   'Speaking of instant gratification, I figured we might need it',
#   'I mean, only if you want to',
#   'EVAN: (spoken) Definitely',
#   'LARRY: (sung)',
#   'Some people say just use a microwave',
#   'Or try that "run it through hot water" technique',
#   'Well, they can gloat about the time they saved',
#   "'til they gotta buy another glove next week",
#   'It just takes a little patience',
#   'Takes a little time',
#   'A little perseverance',
#   'And a little uphill climb',
#   "And it's the hard way, but it's the right way",
#   'The right way...',
#   "There's a right way in everything you do",
#   'Keep that grit',
#   'Follow through',
#   "Even when everyone around you thinks you're crazy",
#   'Even when everyone around you lets things go',
#   "And if you're prepping for some test",
#   "Or if you're miles from some goal",
#   "Or you're just trying to do what's best",
#   "For a kid who's lost control",
#   'You do the hard thing',
#   "And that's the right thing",
#   "Yeah, that's the right way",
#   'Last Update: November, 23rd 2016',
#   'Only Us',
#   'ZOE:',
#   "I don't need you to sell me on reasons to want you",
#   "I don't need you to search for the proof that I should",
#   "You don't have to convince me",
#   "You don't have to be scared you're not enough",
#   "'Cause what we've got going is good",
#   "I don't need more reminders of all that's been broken",
#   "I don't need you to fix what I'd rather forget",
#   'Clear the slate and start over',
#   'Try to quiet the noises in your head',
#   "We can't compete with all that",
#   "So what if it's us",
#   "What if it's us",
#   'And only us',
#   "And what came before won't count anymore or matter",
#   'Can we try that?',
#   "What if it's you",
#   "And what if it's me",
#   "And what if that's all that we need it to be",
#   'And the rest of the world falls away',
#   'What do you say?',
#   "EVAN: I never thought there'd be someone like you who would want me",
#   'ZOE: Well...',
#   'EVAN:',
#   'So I give you ten thousand reasons to not let me go',
#   'But if you really see me',
#   'If you like me for me and nothing else',
#   "Well, that's all that I've wanted for longer that you could possibly know",
#   'So it can be us',
#   'It can be us',
#   'And only us',
#   "And what came before won't count anymore or matter",
#   'We can try that',
#   "EVAN & ZOE: It's not so impossible",
#   'EVAN: Nobody else but the two of us here',
#   "EVAN & ZOE: 'Cause you're saying it's possible",
#   'ZOE: We can just watch the whole world disappear',
#   "EVAN & ZOE: 'Til you're the only one I still know how to see",
#   "EVAN: It's just you and me",
#   'ZOE:',
#   "It'll be us",
#   "It'll be us",
#   'And only us',
#   "And what came before won't count anymore",
#   'EVAN & ZOE:',
#   'We can try that',
#   'You and me',
#   "That's all that we need it to be",
#   'And the rest of the world falls away',
#   'And the rest of the world falls away',
#   'The world falls away',
#   'The world falls away',
#   "And it's only us",
#   'Last Update: November, 23rd 2016',
#   'Good For You',
#   'HEIDI:',
#   'So you found a place where the grass is greener',
#   'And you jumped the fence to the other side',
#   'Is it good?',
#   'Are they giving you a world I could never provide?',
#   "Well I hope you're proud of your big decision",
#   "Yeah, I hope it's all that you want and more",
#   "Now you're free from the agonizing life you were living before",
#   'Say what you need to say',
#   'So that you get to walk away',
#   'It would kill you to have to stay trapped',
#   "When you've got something new",
#   "Well I'm sorry you had it rough",
#   "I'm sorry I'm not enough",
#   'Thank God they rescued you',
#   'So you got what you always wanted',
#   'So you got your dream come true',
#   'Good for you',
#   'Good for you, you , you',
#   'Got a taste of a life so perfect',
#   'So you did what you had to do',
#   'Good for you',
#   'Good for you',
#   'ALANA: (spoken) Why did Connor kill himself?',
#   'EVAN: (spoken) Wait what?',
#   'ALANA: (spoken)',
#   'He was doing better',
#   "That's what he told you in every single email",
#   'and then a month later he kills himself?',
#   'How does that make sense?',
#   'EVAN: (spoken)',
#   'Why are you so obsessed with this?',
#   "You didn't even know him",
#   "ALANA: (spoken) Because it's important!",
#   'EVAN: (spoken)',
#   'Because he was your lab partner?',
#   "Or because, I don't know",
#   'Maybe because you want to add another extracurricular for your college application',
#   'ALANA: (spoken)',
#   "Because I know what it's like to feel invisible, just like Connor!",
#   'To feel invisible and alone and like nobody would even notice if you vanished into thin air',
#   'I bet you used to know what that felt like, too!',
#   'EVAN: (spoken)',
#   'We need more emails',
#   'Emails showing that he was getting worse',
#   "This isn't funny!",
#   "JARED: (spoken) Oh I think it's hilarious!",
#   "I think everyone would probably think it's hilarious",
#   'EVAN: (spoken) What is that supposed to mean?',
#   'JARED: (spoken) It means you should remember who your friends are',
#   'EVAN: (spoken) I thought the only reason you even talk to me is because of your car insurance?',
#   'JARED: (spoken) So?',
#   "EVAN: (spoken) So? Maybe the only reason you talk to me, Jared, is because you don't have any other friends!",
#   'JARED: (spoken) I could tell everyone everything!',
#   'EVAN: (spoken) Great! Go ahead, do it! Tell everyone how you helped write emails pretending to be a kid who killed himself.',
#   'JARED: (spoken) Fuck you, Evan! Asshole',
#   'ALANA:',
#   'Did it cross your mind to be slightly sorry?',
#   'Do you even care that you might be wrong?',
#   'Was it fun?',
#   'Well I hope you had a blast while you dragged me along',
#   'JARED:',
#   'And you say what you need to say',
#   'And you play who you need to play',
#   "And if somebody's in your way",
#   'Crush them and leave them behind',
#   "Well I guess since I'm not of use",
#   'Go ahead you can cut me loose',
#   'Go ahead now',
#   "JARED & ALANA: I won't mind",
#   'HEIDI:',
#   "I'll shut my mouth and I'll let you go",
#   'Is that good for you?',
#   'Would that be good for you you you?',
#   'HEIDI & ALANA:',
#   "I'll just sit back while you run the show",
#   'Is that good for you?',
#   'Would that be good for you you you?',
#   'HEIDI, ALANA & JARED:',
#   "I'll shut my mouth and I'll let you go",
#   'Is that good for you?',
#   'Would that be good for you you you?',
#   "I'll just sit back while you run the show",
#   'Is that good for you?',
#   'Good for you',
#   'EVAN:',
#   '[?] time to think',
#   'but the book is about to sink',
#   "Can't erase what I wrote and [?]",
#   'Tell me how could you change the story?',
#   'EVAN:',
#   'Stop it stop it!Just let me go!',
#   'ALANA, JARED & HEIDI:',
#   'So you got what you always wanted',
#   'So you got your dream come true',
#   'Good for you',
#   'Good for you, you , you',
#   'Got a taste of a life so perfect',
#   "Now you've changed into someone new",
#   'Good for you',
#   'Good for you',
#   'Good for you',
#   'Good for you',
#   'So you got what you always wanted',
#   'Last Update: November, 23rd 2016',
#   'Words Fail',
#   'EVAN:',
#   'So I just stand here sorry',
#   'Searching for something to say',
#   'Something to say',
#   'Words fail, words fail',
#   "There's nothing I can say",
#   'I guess I thought I could be part of this',
#   'I never had this kind of thing before',
#   'I never had that perfect girl',
#   'who somehow could see the good part of me',
#   'And I never had the dad who stuck it out',
#   'No corny jokes or baseball gloves',
#   'No mom who just was there',
#   "'Cause mom was all that she had to be",
#   "That's not a worthy explanation",
#   'I know there is nothing',
#   "Nothing can make sense of all these things I've done",
#   'Words fail, words fail',
#   "There's nothing I can say",
#   'Except sometimes you see everything you want',
#   'And sometimes you see everything you wish you had',
#   "It's right there, right there, right there",
#   'In front of you',
#   "And you wanna believe it's true",
#   'So you make it true',
#   'And you think maybe everybody wants it',
#   'And needs it a little bit too',
#   'This was just a sad invention',
#   "It wasn't real, I know",
#   'But we were happy',
#   "I guess I couldn't let that go",
#   "I guess I couldn't give that up",
#   'I guess I wanted to believe it',
#   "'Cause if I just believe",
#   "Then I don't have to see what's really there",
#   "No, I'd rather pretend I'm something better than",
#   'These broken parts',
#   "Pretend I'm something other than this mess that I am",
#   "'Cause then I don't have to look at it",
#   'And no one gets to look at it',
#   'No one can really see',
#   "'Cause I've learned to slam on the brake",
#   'Before I even turn the key',
#   'Before I make a mistake',
#   'Before I lead with the worst of me',
#   'I never let them see the worst of me',
#   "'Cause what if everyone saw?",
#   'What if everyone knew?',
#   'Would they like what they saw?',
#   'Or would they hate it too?',
#   "Will I just keep running away from what's true?",
#   'All I ever do is run',
#   'So how do I step in',
#   'Step into the sun',
#   'Step into the sun',
#   'Last Update: November, 23rd 2016',
#   'So Big/So Small',
#   'HEIDI:',
#   'It was a February day',
#   'When your dad before going away',
#   'A U-Haul truck in the driveway',
#   'The day was suddenly real',
#   'I told you not to come outside',
#   'But you saw that truck',
#   'And you smiled so wide',
#   'A real live truck in your driveway',
#   'We let you sit behind the wheel',
#   'Good-bye, good-bye',
#   "Now it's just me and my little guy",
#   'And the house felt so big, and I felt so small',
#   'The house felt so big, and I felt so small',
#   'That night I tucked you into bed',
#   'I will never forget how you sat up and said',
#   '"Is there another truck coming to our driveway',
#   'A truck that will take mommy away?"',
#   'And the house felt so big, and I felt so small',
#   'The house felt so big, and I knew',
#   'There would be moments like this',
#   'And I knew',
#   "There would be space I couldn't fill",
#   'And I knew',
#   "I'd come up short a million different ways",
#   'And I did',
#   'And I do',
#   'And I will',
#   'But like that February day',
#   'I will take your hand, squeeze it tightly and say',
#   "There's not another truck in the driveway",
#   "Your mom isn't going anywhere",
#   'Your mom is staying right here',
#   "Your mom isn't going anywhere",
#   'Your mom is staying right here',
#   'No matter what',
#   "I'll be here",
#   'When it feels so big',
#   "'til it all feels so small",
#   'When it feels so big',
#   "'til it all feels so small",
#   "'til it all feels so small",
#   'Last Update: November, 23rd 2016',
#   'For Forever (Reprise)',
#   'EVAN: (spoken)',
#   'Dear Evan Hansen,',
#   "Today is going to be a good day and here's why",
#   "because today, no matter what else, today at least, you're you.",
#   'No secrets or lying.',
#   'Just you',
#   'Maybe someday everything that happened,',
#   'Maybe it will all feel like a distant memory.',
#   'Maybe ten years from now, no-one will even remember about the Connor Project or me.',
#   "They'll just come here and pick apples and enjoy their picnics and that'll be it.",
#   'EVAN: (sung)',
#   'All we see is sky for forever',
#   'Let the world pass by for forever',
#   'Feels like we could go on for forever this way',
#   'This way',
#   'EVAN: (spoken)',
#   'Maybe some day some other kid is going to be standing out here, staring at the trees.',
#   'Feeling so alone,wondering if the world might look different from all the way up there.',
#   "Then maybe he'll start climbing one branch at a time",
#   "and he'll keep going, even when it seems like he can't find another foothold.",
#   'Even when it feels hopeless, like everything is telling him to just let go.',
#   "This time, maybe this time he won't let go.",
#   "He'll just hold on.",
#   "He'll hold on and he'll keep going.",
#   "He'll keep going until he sees the sun.",
#   'WHOLE CAST:',
#   'All we see is light for forever',
#   '(all we see is light for forever)',
#   "'cause the sun shines bright for forever",
#   '(the sun shines bright)',
#   'Life will be alright for forever this way',
#   'This way',
#   'All we see is light',
#   'Watch the sun burn bright',
#   'We will be alright for forever this way',
#   'All we see is sky for forever',
#   'EVAN: All I see is sky for forever',
#   'Last Update: November, 23rd 2016'],
#  'script': [],
#  'song_titles': ['http://www.allmusicals.com/lyrics/dearevanhansen/anybodyhaveamap.htm',
#   'http://www.allmusicals.com/lyrics/dearevanhansen/wavingthroughawindow.htm',
#   'http://www.allmusicals.com/lyrics/dearevanhansen/forforever.htm',
#   'http://www.allmusicals.com/lyrics/dearevanhansen/sincerelyme.htm',
#   'http://www.allmusicals.com/lyrics/dearevanhansen/requiem.htm',
#   'http://www.allmusicals.com/lyrics/dearevanhansen/ificouldtellher.htm',
#   'http://www.allmusicals.com/lyrics/dearevanhansen/disappear.htm',
#   'http://www.allmusicals.com/lyrics/dearevanhansen/youwillbefound.htm',
#   'http://www.allmusicals.com/lyrics/dearevanhansen/sincerelymereprise.htm',
#   'http://www.allmusicals.com/lyrics/dearevanhansen/tobreakinaglove.htm',
#   'http://www.allmusicals.com/lyrics/dearevanhansen/onlyus.htm',
#   'http://www.allmusicals.com/lyrics/dearevanhansen/goodforyou.htm',
#   'http://www.allmusicals.com/lyrics/dearevanhansen/wordsfail.htm',
#   'http://www.allmusicals.com/lyrics/dearevanhansen/sobigsosmall.htm',
#   'http://www.allmusicals.com/lyrics/dearevanhansen/forforeverreprise.htm']}

# %%
f = open("broadway_lyrics_v5.pkl","wb")
pickle.dump(bd,f)
f.close()

# %%
printable_names = {}
for key in bd:
    if key.endswith(', The'):
        printable_names[key] = 'The ' + key[:key.rfind(',')]
    elif key.endswith(', An'):
        printable_names[key] = 'An ' + key[:key.rfind(',')]
    elif key.endswith(', A'):
        printable_names[key] = 'A ' + key[:key.rfind(',')]
    else:
        printable_names[key] = key

# %%
printable_names
# Out:
# {'110 in the Shade': '110 in the Shade',
#  '13': '13',
#  '1776': '1776',
#  '25th Annual Putnam County Spelling Bee': '25th Annual Putnam County Spelling Bee',
#  '42nd Street': '42nd Street',
#  '70, Girls, 70': '70, Girls, 70',
#  '9 to 5': '9 to 5',
#  'A Day in Hollywood / A Night in the Ukraine': 'A Day in Hollywood / A Night in the Ukraine',
#  'Ace': 'Ace',
#  'Across the Universe': 'Across the Universe',
#  'Act, The': 'The Act',
#  'Addams Family, The': 'The Addams Family',
#  'Adding Machine': 'Adding Machine',
#  'Adrift In Macao': 'Adrift In Macao',
#  'Adventures of Tom Sawyer, The': 'The Adventures of Tom Sawyer',
#  'Aida': 'Aida',
#  "Ain't Misbehavin'": "Ain't Misbehavin'",
#  "Ain't Too Proud": "Ain't Too Proud",
#  'Aladdin': 'Aladdin',
#  "Alas! Alack! Zorro's Back!": "Alas! Alack! Zorro's Back!",
#  'All Shook Up': 'All Shook Up',
#  'Allegro': 'Allegro',
#  'Altar Boyz': 'Altar Boyz',
#  'American Idiot': 'American Idiot',
#  'American Mall': 'American Mall',
#  'American in Paris, An': 'An American in Paris',
#  'Anastasia': 'Anastasia',
#  'Andrew Lloyd Webber Divas': 'Andrew Lloyd Webber Divas',
#  'Anna Karenina': 'Anna Karenina',
#  'Annie': 'Annie',
#  'Annie Get Your Gun': 'Annie Get Your Gun',
#  'Anyone Can Whistle': 'Anyone Can Whistle',
#  'Anything Goes': 'Anything Goes',
#  'Applause': 'Applause',
#  'Apple Tree, The': 'The Apple Tree',
#  'Ark, The': 'The Ark',
#  'As Thousands Cheer': 'As Thousands Cheer',
#  'Aspects of Love': 'Aspects of Love',
#  'Assassins': 'Assassins',
#  'Avenue Q': 'Avenue Q',
#  'Babes In Arms': 'Babes In Arms',
#  'Baby': 'Baby',
#  'Bad Girls': 'Bad Girls',
#  'Bajour': 'Bajour',
#  "Baker's Wife, The": "The Baker's Wife",
#  "Band's Visit": "Band's Visit",
#  'Bandstand': 'Bandstand',
#  'Bare: A Pop Opera': 'Bare: A Pop Opera',
#  'Bark! The Musical': 'Bark! The Musical',
#  'Barnum': 'Barnum',
#  'Bat Boy': 'Bat Boy',
#  'Be More Chill': 'Be More Chill',
#  'Beautiful Game, The': 'The Beautiful Game',
#  'Beautiful: The Carole King': 'Beautiful: The Carole King',
#  'Bells Are Ringing': 'Bells Are Ringing',
#  'Ben Franklin in Paris': 'Ben Franklin in Paris',
#  'Bernarda Alba': 'Bernarda Alba',
#  'Best Foot Forward': 'Best Foot Forward',
#  'Best Little Whorehouse in Texas, The': 'The Best Little Whorehouse in Texas',
#  'Best of Broadway, The': 'The Best of Broadway',
#  'Big': 'Big',
#  'Big Fish': 'Big Fish',
#  'Big River': 'Big River',
#  'Billy Elliot': 'Billy Elliot',
#  'Blood Brothers': 'Blood Brothers',
#  'Bombay Dreams': 'Bombay Dreams',
#  'Book of Mormon, The': 'The Book of Mormon',
#  'Bounce': 'Bounce',
#  'Boy Friend, The': 'The Boy Friend',
#  'Boy From Oz, The': 'The Boy From Oz',
#  'Boys From Syracuse, The': 'The Boys From Syracuse',
#  'Bridges of Madison County, The': 'The Bridges of Madison County',
#  'Brigadoon': 'Brigadoon',
#  'Bright Lights, Big City': 'Bright Lights, Big City',
#  "Bring In 'Da Noise, Bring In 'Da Funk": "Bring In 'Da Noise, Bring In 'Da Funk",
#  'Bring It On': 'Bring It On',
#  'Bronx Tale': 'Bronx Tale',
#  'Brooklyn': 'Brooklyn',
#  'Bullets Over Broadway': 'Bullets Over Broadway',
#  'Burn The Floor': 'Burn The Floor',
#  'Busker Alley': 'Busker Alley',
#  'By Jeeves': 'By Jeeves',
#  'Bye Bye Birdie': 'Bye Bye Birdie',
#  'Cabaret': 'Cabaret',
#  'Calamity Jane': 'Calamity Jane',
#  'Call Me Madam': 'Call Me Madam',
#  'Camelot': 'Camelot',
#  'Can-Can': 'Can-Can',
#  'Candide': 'Candide',
#  'Cannibal': 'Cannibal',
#  'Carnival': 'Carnival',
#  'Caroline, or Change': 'Caroline, or Change',
#  'Carousel': 'Carousel',
#  'Catch Me If You Can': 'Catch Me If You Can',
#  'Catered Affair, A': 'A Catered Affair',
#  'Cats': 'Cats',
#  'Chaplin': 'Chaplin',
#  'Charlie and Algernon': 'Charlie and Algernon',
#  'Charlie and the Chocolate Factory': 'Charlie and the Chocolate Factory',
#  'Chess': 'Chess',
#  'Chess in Concert [LIVE]': 'Chess in Concert [LIVE]',
#  'Chicago': 'Chicago',
#  'Children Of Eden': 'Children Of Eden',
#  "Children's Letters to God": "Children's Letters to God",
#  'Chitty Chitty Bang Bang': 'Chitty Chitty Bang Bang',
#  'Chorus Line, A': 'A Chorus Line',
#  'Christmas Carol, A': 'A Christmas Carol',
#  'Cinderella: Songs from the Classic Fairy Tale': 'Cinderella: Songs from the Classic Fairy Tale',
#  'City Of Angels': 'City Of Angels',
#  'Civil War, The': 'The Civil War',
#  'Civil War: The Complete Work, The': 'The Civil War: The Complete Work',
#  'Class Act, A': 'A Class Act',
#  'Closer Than Ever': 'Closer Than Ever',
#  'Colma': 'Colma',
#  'Color Purple, The': 'The Color Purple',
#  'Come From Away': 'Come From Away',
#  'Commentary, The Musical': 'Commentary, The Musical',
#  'Company': 'Company',
#  'Connecticut Yankee, A': 'A Connecticut Yankee',
#  'Contact': 'Contact',
#  'Copacabana': 'Copacabana',
#  'Corpse Bride': 'Corpse Bride',
#  'Crazy For You': 'Crazy For You',
#  'Cry-Baby': 'Cry-Baby',
#  'Curtains': 'Curtains',
#  'Damn Yankees': 'Damn Yankees',
#  'Dance of the Vampires': 'Dance of the Vampires',
#  'Dear Evan Hansen': 'Dear Evan Hansen',
#  'Dear World': 'Dear World',
#  'Dirty Rotten Scoundrels': 'Dirty Rotten Scoundrels',
#  "Disney's Beauty And The Beast": "Disney's Beauty And The Beast",
#  'Disney: 60 Years of Musical Magic': 'Disney: 60 Years of Musical Magic',
#  'Do Black Patent Leather Shoes Really Reflect Up?': 'Do Black Patent Leather Shoes Really Reflect Up?',
#  'Do I Hear A Waltz?': 'Do I Hear A Waltz?',
#  'Do Re Mi': 'Do Re Mi',
#  'Dracula': 'Dracula',
#  'Dreamgirls': 'Dreamgirls',
#  'Drowsy Chaperone, The': 'The Drowsy Chaperone',
#  'Edges: A Song Cycle': 'Edges: A Song Cycle',
#  'Elegies: A Song Cycle': 'Elegies: A Song Cycle',
#  'Ernest in Love': 'Ernest in Love',
#  'Evil Dead': 'Evil Dead',
#  'Evita': 'Evita',
#  'Face the Music': 'Face the Music',
#  'Falsettoland': 'Falsettoland',
#  'Falsettos': 'Falsettos',
#  'Fame': 'Fame',
#  'Fame Becomes Me': 'Fame Becomes Me',
#  'Fanny': 'Fanny',
#  'Fantasticks, The': 'The Fantasticks',
#  'Fiddler on the Roof': 'Fiddler on the Roof',
#  'Finding Neverland': 'Finding Neverland',
#  "Finian's Rainbow": "Finian's Rainbow",
#  'Fiorello': 'Fiorello',
#  'First Date': 'First Date',
#  'Five Course Love': 'Five Course Love',
#  'Five Guys Named Moe': 'Five Guys Named Moe',
#  'Flora The Red Menace': 'Flora The Red Menace',
#  'Flower Drum Song': 'Flower Drum Song',
#  'Floyd Collins': 'Floyd Collins',
#  'Follies': 'Follies',
#  'Footloose': 'Footloose',
#  'Forbidden Broadway Goes to Rehab': 'Forbidden Broadway Goes to Rehab',
#  'Forbidden Broadway, Vols. 1-4': 'Forbidden Broadway, Vols. 1-4',
#  'Forever Plaid': 'Forever Plaid',
#  'Fosse': 'Fosse',
#  'Frankenstein: A New Musical': 'Frankenstein: A New Musical',
#  'Frogs, The': 'The Frogs',
#  'Frozen': 'Frozen',
#  'Full Monty, The': 'The Full Monty',
#  'Fun Home': 'Fun Home',
#  'Funny Girl': 'Funny Girl',
#  'Funny Thing Happened On The Way To The Forum, A': 'A Funny Thing Happened On The Way To The Forum',
#  'Gay Divorce, The': 'The Gay Divorce',
#  "Gentleman's Guide to Love and Murder, A": "A Gentleman's Guide to Love and Murder",
#  'Gentlemen Prefer Blondes': 'Gentlemen Prefer Blondes',
#  'George M!': 'George M!',
#  'Ghost the Musical': 'Ghost the Musical',
#  'Gigi': 'Gigi',
#  'Glorious Ones, The': 'The Glorious Ones',
#  'Glory Days': 'Glory Days',
#  'Godspell': 'Godspell',
#  'Golden Boy': 'Golden Boy',
#  'Gone Missing': 'Gone Missing',
#  'Good News': 'Good News',
#  'Goodbye Girl, The': 'The Goodbye Girl',
#  'Grand Hotel': 'Grand Hotel',
#  'Greetings From Yorkville': 'Greetings From Yorkville',
#  'Grey Gardens': 'Grey Gardens',
#  'Grind': 'Grind',
#  'Groundhog Day': 'Groundhog Day',
#  'Gutenberg! The Musical!': 'Gutenberg! The Musical!',
#  'Guys and Dolls': 'Guys and Dolls',
#  'Gypsy': 'Gypsy',
#  'Hadestown': 'Hadestown',
#  'Hair': 'Hair',
#  'Hairspray': 'Hairspray',
#  'Hallelujah, Baby!': 'Hallelujah, Baby!',
#  'Hamilton': 'Hamilton',
#  'Happiest Girl in the World, The': 'The Happiest Girl in the World',
#  'Happy Days': 'Happy Days',
#  'Happy End': 'Happy End',
#  'Head Over Heels': 'Head Over Heels',
#  'Heathers': 'Heathers',
#  'Hedwig And The Angry Inch': 'Hedwig And The Angry Inch',
#  'Hello, Dolly': 'Hello, Dolly',
#  'High Fidelity': 'High Fidelity',
#  'High School Musical': 'High School Musical',
#  'High School Musical 2': 'High School Musical 2',
#  'High School Musical 3: Senior Year': 'High School Musical 3: Senior Year',
#  'High School Musical On Stage': 'High School Musical On Stage',
#  'High Society': 'High Society',
#  'Honk': 'Honk',
#  'How the Grinch Stole Christmas': 'How the Grinch Stole Christmas',
#  'How to Succeed in Business Without Really Trying': 'How to Succeed in Business Without Really Trying',
#  'I Do! I Do!': 'I Do! I Do!',
#  'I Love My Wife': 'I Love My Wife',
#  'I Love You Because': 'I Love You Because',
#  "I Love You, You're Perfect, Now Change": "I Love You, You're Perfect, Now Change",
#  'I Sing': 'I Sing',
#  'If/Then': 'If/Then',
#  'Illya Darling': 'Illya Darling',
#  'In Trousers': 'In Trousers',
#  'In the Heights': 'In the Heights',
#  'Into the Woods': 'Into the Woods',
#  'Irene': 'Irene',
#  "It's Only Life": "It's Only Life",
#  'Jacques Brel Is Alive and Well and Living in Paris': 'Jacques Brel Is Alive and Well and Living in Paris',
#  'Jane Eyre': 'Jane Eyre',
#  'Jekyll & Hyde': 'Jekyll & Hyde',
#  "Jelly's Last Jam": "Jelly's Last Jam",
#  'Jennie': 'Jennie',
#  'Jerry Springer: the Opera': 'Jerry Springer: the Opera',
#  'Jersey Boys': 'Jersey Boys',
#  'Jesus Christ Superstar': 'Jesus Christ Superstar',
#  'Joseph And The Amazing Technicolor Dreamcoat': 'Joseph And The Amazing Technicolor Dreamcoat',
#  'Jungle Book': 'Jungle Book',
#  'Just So': 'Just So',
#  'King and I, The': 'The King and I',
#  'Kinky Boots': 'Kinky Boots',
#  'Kismet': 'Kismet',
#  'Kiss Me, Kate': 'Kiss Me, Kate',
#  'Kiss Of The Spider Woman': 'Kiss Of The Spider Woman',
#  "Kitty's Kisses": "Kitty's Kisses",
#  'La Cage Aux Folles': 'La Cage Aux Folles',
#  'Last 5 Years, The': 'The Last 5 Years',
#  'Leader of the Pack': 'Leader of the Pack',
#  'Legally Blonde': 'Legally Blonde',
#  'Lennon': 'Lennon',
#  'Les Miserables': 'Les Miserables',
#  'Lestat': 'Lestat',
#  "Li'l Abner": "Li'l Abner",
#  'Light in the Piazza': 'Light in the Piazza',
#  'Likes of US, The': 'The Likes of US',
#  'Lion King': 'Lion King',
#  'Little Fish': 'Little Fish',
#  'Little Mary Sunshine': 'Little Mary Sunshine',
#  'Little Me': 'Little Me',
#  'Little Mermaid': 'Little Mermaid',
#  'Little Night Music': 'Little Night Music',
#  'Little Shop of Horrors': 'Little Shop of Horrors',
#  'Little Women': 'Little Women',
#  "Liza's at the Palace": "Liza's at the Palace",
#  'Lone Star Love': 'Lone Star Love',
#  'Lord of the Rings': 'Lord of the Rings',
#  'Love Never Dies': 'Love Never Dies',
#  'Love Online': 'Love Online',
#  'LoveMusik': 'LoveMusik',
#  'Lucky Stiff': 'Lucky Stiff',
#  'Mack & Mabel': 'Mack & Mabel',
#  'Magic Tree House': 'Magic Tree House',
#  'Make Me A Song': 'Make Me A Song',
#  'Mame': 'Mame',
#  'Mamma Mia!': 'Mamma Mia!',
#  'Man of La Mancha': 'Man of La Mancha',
#  'Man of No Importance, A': 'A Man of No Importance',
#  'March Of The Falsettos': 'March Of The Falsettos',
#  'Marguerite': 'Marguerite',
#  'Marie Christine': 'Marie Christine',
#  'Marvelous Wonderettes, The': 'The Marvelous Wonderettes',
#  'Mary Poppins': 'Mary Poppins',
#  'Matilda': 'Matilda',
#  'Me Nobody Knows, The': 'The Me Nobody Knows',
#  'Me and Juliet': 'Me and Juliet',
#  'Me and My Girl': 'Me and My Girl',
#  'Mean Girls': 'Mean Girls',
#  'Meet Me In St. Louis': 'Meet Me In St. Louis',
#  'Memphis': 'Memphis',
#  'Menopause': 'Menopause',
#  'Merrily We Roll Along': 'Merrily We Roll Along',
#  'Milk And Honey': 'Milk And Honey',
#  'Million Dollar Quartet': 'Million Dollar Quartet',
#  'Miss Liberty': 'Miss Liberty',
#  'Miss Saigon': 'Miss Saigon',
#  'Most Happy Fella, The': 'The Most Happy Fella',
#  'Motown': 'Motown',
#  "Movin' Out": "Movin' Out",
#  'Mr. Mark Twain': 'Mr. Mark Twain',
#  'Mr. President': 'Mr. President',
#  'Music Man, The': 'The Music Man',
#  'My Fair Lady': 'My Fair Lady',
#  'My Favorite Year': 'My Favorite Year',
#  'My Name will always be Alice': 'My Name will always be Alice',
#  'Mystery Of Edwin Drood, The': 'The Mystery Of Edwin Drood',
#  'Myths And Hymns': 'Myths And Hymns',
#  'Naked. Boys Singing!': 'Naked. Boys Singing!',
#  'Narnia': 'Narnia',
#  'Natasha, Pierre, And The Great Comet Of 1812': 'Natasha, Pierre, And The Great Comet Of 1812',
#  'New Brain, A': 'A New Brain',
#  'New Girl in Town': 'New Girl in Town',
#  'Newsies': 'Newsies',
#  'Next to Normal': 'Next to Normal',
#  'Nice Work If You Can Get It': 'Nice Work If You Can Get It',
#  'Nine': 'Nine',
#  'No Strings': 'No Strings',
#  'Notre Dame de Paris': 'Notre Dame de Paris',
#  'Of Thee I Sing': 'Of Thee I Sing',
#  'Oh Captain': 'Oh Captain',
#  'Oh, Kay!': 'Oh, Kay!',
#  'Oklahoma': 'Oklahoma',
#  'Oliver': 'Oliver',
#  'On The Town': 'On The Town',
#  'On Your Feet!': 'On Your Feet!',
#  'On a Clear Day You Can See Forever': 'On a Clear Day You Can See Forever',
#  'On the Record': 'On the Record',
#  'Once On This Island': 'Once On This Island',
#  'Once Upon A Mattress': 'Once Upon A Mattress',
#  'Out Of This World': 'Out Of This World',
#  'Pacific Overtures': 'Pacific Overtures',
#  'Paint Your Wagon': 'Paint Your Wagon',
#  'Pajama Game, The': 'The Pajama Game',
#  'Pal Joey': 'Pal Joey',
#  'Parade': 'Parade',
#  'Passing Strange': 'Passing Strange',
#  'Passion': 'Passion',
#  'People vs. Mona': 'People vs. Mona',
#  'Peter Pan': 'Peter Pan',
#  'Phantom of the Opera, The': 'The Phantom of the Opera',
#  'Pipe Dream': 'Pipe Dream',
#  'Pippin': 'Pippin',
#  'Pirate Queen, The': 'The Pirate Queen',
#  'Pirates of Penzance, The': 'The Pirates of Penzance',
#  'Play On!': 'Play On!',
#  'Pocahontas': 'Pocahontas',
#  'Pretty Faces': 'Pretty Faces',
#  'Pretty Woman': 'Pretty Woman',
#  'Princess and the Frog': 'Princess and the Frog',
#  'Priscilla: Queen of the Desert': 'Priscilla: Queen of the Desert',
#  'Producers': 'Producers',
#  'Prom': 'Prom',
#  'Prom Night': 'Prom Night',
#  'Promises, Promises': 'Promises, Promises',
#  'Pump Boys And Dinettes': 'Pump Boys And Dinettes',
#  'Quadrophenia': 'Quadrophenia',
#  'Queen of the Mist': 'Queen of the Mist',
#  'Quilters': 'Quilters',
#  'REPO! The Genetic Opera': 'REPO! The Genetic Opera',
#  'Radio City Christmas Spectacular': 'Radio City Christmas Spectacular',
#  'Ragtime': 'Ragtime',
#  'Raisin': 'Raisin',
#  'Redhead': 'Redhead',
#  'Reefer Madness': 'Reefer Madness',
#  'Rent': 'Rent',
#  'Ring of Fire': 'Ring of Fire',
#  'Rink, The': 'The Rink',
#  'Roar Of The Greasepaint, The - The Smell Of The Crowd': 'Roar Of The Greasepaint, The - The Smell Of The Crowd',
#  'Rock Of Ages': 'Rock Of Ages',
#  'Rocky Horror Show': 'Rocky Horror Show',
#  "Rodgers and Hammerstein's South Pacific": "Rodgers and Hammerstein's South Pacific",
#  'Rooms: A Rock Romance': 'Rooms: A Rock Romance',
#  'Rude Awakening': 'Rude Awakening',
#  'Salad Days': 'Salad Days',
#  'Saturday Night Fever': 'Saturday Night Fever',
#  'Say, Darling': 'Say, Darling',
#  'Scarlet Pimpernel, The': 'The Scarlet Pimpernel',
#  'School of Rock': 'School of Rock',
#  'Scrooge': 'Scrooge',
#  'Secret Garden, The': 'The Secret Garden',
#  'See What I Wanna See': 'See What I Wanna See',
#  'Seesaw': 'Seesaw',
#  'Seussical': 'Seussical',
#  'Seven Brides For Seven Brothers': 'Seven Brides For Seven Brothers',
#  'She Loves Me': 'She Loves Me',
#  'Shout!': 'Shout!',
#  'Show Boat': 'Show Boat',
#  'Shrek': 'Shrek',
#  'Side Show': 'Side Show',
#  'Silence!': 'Silence!',
#  "Singin' In The Rain": "Singin' In The Rain",
#  'Sister Act The Musical': 'Sister Act The Musical',
#  'Smash': 'Smash',
#  'Smile': 'Smile',
#  "Smokey Joe's Cafe": "Smokey Joe's Cafe",
#  'Snoopy': 'Snoopy',
#  'Snow White And The Seven Dwarfs': 'Snow White And The Seven Dwarfs',
#  'So Long, 174th Street': 'So Long, 174th Street',
#  'Something Rotten!': 'Something Rotten!',
#  'Song & Dance': 'Song & Dance',
#  'Songs For A New World': 'Songs For A New World',
#  'Sound of Music, The': 'The Sound of Music',
#  'South Pacific': 'South Pacific',
#  'Spamalot': 'Spamalot',
#  'Special Victims Unit': 'Special Victims Unit',
#  'Spider-Man, Turn Off the Dark': 'Spider-Man, Turn Off the Dark',
#  'SpongeBob SquarePants': 'SpongeBob SquarePants',
#  'Spoof Odyssey': 'Spoof Odyssey',
#  'Spring Awakening': 'Spring Awakening',
#  'Star Is Born, A': 'A Star Is Born',
#  'Starlight Express': 'Starlight Express',
#  'State Fair': 'State Fair',
#  'Steel Pier': 'Steel Pier',
#  'Story of My Life, The': 'The Story of My Life',
#  'Subways Are for Sleeping': 'Subways Are for Sleeping',
#  'Sugar': 'Sugar',
#  'Summer Stock': 'Summer Stock',
#  "Summer of '42": "Summer of '42",
#  'Sunday in the Park With George': 'Sunday in the Park With George',
#  'Sunset Boulevard': 'Sunset Boulevard',
#  'Sweeney Todd: The Demon Barber of Fleet Street': 'Sweeney Todd: The Demon Barber of Fleet Street',
#  'Sweet Charity': 'Sweet Charity',
#  'Swing!': 'Swing!',
#  'Taboo': 'Taboo',
#  'Take Flight': 'Take Flight',
#  'Take Me Along': 'Take Me Along',
#  'Tale of Two Cities, A': 'A Tale of Two Cities',
#  'Tarzan': 'Tarzan',
#  'Tell Me On A Sunday': 'Tell Me On A Sunday',
#  "That's What Kids Do": "That's What Kids Do",
#  'The Thing About Men': 'The Thing About Men',
#  "They're Playing Our Song": "They're Playing Our Song",
#  'Thoroughly Modern Millie': 'Thoroughly Modern Millie',
#  'Tick, Tick... Boom': 'Tick, Tick... Boom',
#  'Titanic': 'Titanic',
#  'Title Of Show': 'Title Of Show',
#  'Toxic Avenger, The': 'The Toxic Avenger',
#  'Triumph Of Love': 'Triumph Of Love',
#  'Two Gentlemen of Verona': 'Two Gentlemen of Verona',
#  'Unsinkable Molly Brown, The': 'The Unsinkable Molly Brown',
#  'Urinetown': 'Urinetown',
#  'Vanities': 'Vanities',
#  'Very Good Eddie': 'Very Good Eddie',
#  'Very Potter Sequel, A': 'A Very Potter Sequel',
#  'Very Potter, A': 'A Very Potter',
#  'Victor / Victoria': 'Victor / Victoria',
#  'Waitress': 'Waitress',
#  'Walmartopia': 'Walmartopia',
#  'War Paint': 'War Paint',
#  'Water Babies': 'Water Babies',
#  'We Will Rock You': 'We Will Rock You',
#  'Wedding Singer': 'Wedding Singer',
#  'West Side Story': 'West Side Story',
#  'White Christmas': 'White Christmas',
#  "Who's Tommy, The": "The Who's Tommy",
#  'Wicked': 'Wicked',
#  'Wild Party': 'Wild Party',
#  'Wildcat': 'Wildcat',
#  'Will Rogers Follies, The': 'The Will Rogers Follies',
#  'Wiz, The': 'The Wiz',
#  'Wizard Of Oz, The': 'The Wizard Of Oz',
#  'Woman In White': 'Woman In White',
#  'Women on the Verge of a Nervous Breakdown': 'Women on the Verge of a Nervous Breakdown',
#  'Wonderful Town': 'Wonderful Town',
#  "Wonderland: Alice's New Musical Adventure": "Wonderland: Alice's New Musical Adventure",
#  'Working': 'Working',
#  'Xanadu': 'Xanadu',
#  'Yank!': 'Yank!',
#  'Year with Frog and Toad, A': 'A Year with Frog and Toad',
#  "You're a Good Man, Charlie Brown": "You're a Good Man, Charlie Brown",
#  'Young Frankenstein': 'Young Frankenstein',
#  'Z, the Masked Musical of Zorro': 'Z, the Masked Musical of Zorro',
#  "Zanna, Don't": "Zanna, Don't",
#  'Zombie Prom': 'Zombie Prom',
#  'Zorro': 'Zorro'}

# %%
backend_to_proper = printable_names
proper_to_backend = {y:x for x,y in backend_to_proper.items()}

# %%
import json

# %%
with open('backend_to_proper.json', 'w') as fp:
    json.dump(backend_to_proper, fp)
with open('proper_to_backend.json', 'w') as fp:
    json.dump(proper_to_backend, fp)
